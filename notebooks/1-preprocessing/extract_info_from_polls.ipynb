# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import heapq

from sklearn.base import BaseEstimator, TransformerMixin

import us
STATES_DICT = us.states.mapping('name', 'abbr')
GRADE_TO_SCORE = {'A+':13, 'A':12, 'A-':11, 'B+':10, 'B':9, 'B-':8, 
                  'C+':7, 'C':6, 'C-':5, 'D+':4, 'D':3, 'D-':2, 'F':1}

from pathlib import Path
DATA_DIR = Path('..')/'..'/'data'

# %% [markdown]
# # Extract info purely from RCP polling data
#
# First, taking a look at raw RCP data. These are separated into house, senate, and governor (process can be found in the Practice_with_Polls notebook).

# %%
house = pd.read_csv(DATA_DIR/'cleaned'/'RCP_house_Final.csv')
house.head()
# Out:
#                           Race/Topic (Click to Sort)      Poll  \
# 0  Pennsylvania 12th District Special Election - ...   PPP (D)
# 1  New Hampshire 1st District - Guinta vs. Shea-P...   PPP (D)
# 2        New Hampshire 2nd District - Bass vs. Swett   PPP (D)
# 3  New Hampshire 1st District - Guinta vs. Shea-P...  WMUR/UNH
# 4        New Hampshire 2nd District - Bass vs. Swett  WMUR/UNH
#
#                      Results     Spread        Date  Year
# 0         Burns 44, Critz 41   Burns +3  2010-04-20  2010
# 1  Guinta 46, Shea-Porter 45  Guinta +1  2010-04-22  2010
# 2          Bass 47, Swett 32   Bass +15  2010-04-22  2010
# 3  Guinta 42, Shea-Porter 38  Guinta +4  2010-04-30  2010
# 4          Bass 44, Swett 27   Bass +17  2010-04-30  2010

# %%
senate = pd.read_csv(DATA_DIR/'cleaned'/'RCP_senate_Final.csv')
senate.head()
# Out:
#                   Race/Topic (Click to Sort)                 Poll  \
# 0  Florida Senate - Rubio vs. Meek vs. Crist           Quinnipiac
# 1      Arkansas Senate - Boozman vs. Lincoln  R2000/Daily Kos (D)
# 2       Arkansas Senate - Boozman vs. Halter  R2000/Daily Kos (D)
# 3            Florida Senate - Rubio vs. Meek           Quinnipiac
# 4        Florida Senate - Republican Primary           Quinnipiac
#
#                        Results      Spread        Date  Year
# 0  Crist 32, Rubio 30, Meek 24    Crist +2  2010-04-15  2010
# 1       Boozman 50, Lincoln 43  Boozman +7  2010-04-15  2010
# 2        Boozman 48, Halter 41  Boozman +7  2010-04-15  2010
# 3            Rubio 42, Meek 38    Rubio +4  2010-04-15  2010
# 4           Rubio 56, Crist 33   Rubio +23  2010-04-15  2010

# %%
governor = pd.read_csv(DATA_DIR/'cleaned'/'RCP_governor_Final.csv')
governor.head()
# Out:
#                      Race/Topic (Click to Sort)               Poll  \
# 0  Colorado Governor - McInnis vs. Hickenlooper  Rasmussen Reports
# 1         Arizona Governor - Republican Primary  Rasmussen Reports
# 2        New York Governor - Republican Primary              Siena
# 3            New York Governor - Levy vs. Cuomo              Siena
# 4           New York Governor - Lazio vs. Cuomo              Siena
#
#                                      Results      Spread        Date  Year
# 0                Hickenlooper 42, McInnis 48  McInnis +6  2010-04-16  2010
# 1  Brewer 26, Mills 18, Martin 12, Munger 14   Brewer +8  2010-04-17  2010
# 2             Lazio 29, Levy 15, Paladino 13   Lazio +14  2010-04-18  2010
# 3                          Cuomo 58, Levy 23   Cuomo +35  2010-04-18  2010
# 4                         Cuomo 61, Lazio 24   Cuomo +37  2010-04-18  2010

# %% [markdown]
# Below is a class that cleans RCP data.

# %%
class ExtractInfo(BaseEstimator, TransformerMixin):
    """
    Extract information from RealClearPolitics polling data.
    
    Parameters
    ----------
    race_type : string
        Type of race. Supported race types:
            - 'house'
            - 'senate'
            - 'governor'
    """
    def __init__(self, race_type):
        if race_type in ['house', 'senate', 'governor']:
            self.race_type = race_type
        else:
            raise NotImplementedError(f"Race type '{race_type}' is not supported")
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):     
        # Extract race name
        race_name = X['Race/Topic (Click to Sort)'] 
        race_name = race_name.str.split(' - ').map(lambda x: x[0].strip())
        
        # Extract state
        state = race_name.copy()
        if self.race_type == 'house':
            state = state.str.replace('At-Large', '0')
            state = state.str.extract(r"(.*) \d.*", expand=False).map(STATES_DICT)
        elif self.race_type == 'senate':
            state = state.str.extract(r"(.*) Senate", expand=False).map(STATES_DICT)
        elif self.race_type == 'governor':
            state = state.str.extract(r"(.*) Governor", expand=False).map(STATES_DICT)
        
        # Extract candidate names and values
        all_poll_results = X['Results'].str.split(',')
        candidates = []
        for row in all_poll_results:
            poll_results = {}
            for candidate in row:
                split = candidate.split()
                candidate_name = ' '.join([x.strip().lower() for x in split[:-1]]) if len(split) > 1 else split[0]
                candidate_value = float(split[-1]) if len(split) > 1 else 0
                
                poll_results[candidate_name] = candidate_value
            
            candidates.append(poll_results)
        candidates = pd.Series(candidates)
            
        # Extract top two candidates
        relevant_candidates = candidates.apply(lambda row: heapq.nlargest(2, row, key=row.get))
            
        # Extract spread
        spread_split = X['Spread'].str.split()
        poll_leader = spread_split.map(lambda x: ' '.join(x[:-1]).lower() if len(x) > 1 else np.nan)
        poll_spread = spread_split.map(lambda x: float(x[-1]) if len(x) > 1 else np.nan)
        
        return pd.DataFrame({'race_name': race_name.str.lower(),
                             'race_type': self.race_type,
                             'state': state,
                             'top_candidates': relevant_candidates,
                             'pollster': X['Poll'].str.lower(),
                             'poll_results': candidates,
                             'poll_leader': poll_leader,
                             'poll_spread': poll_spread,
                             'date': X['Date']})

# %%
ei_house = ExtractInfo('house')
ei_senate = ExtractInfo('senate')
ei_governor = ExtractInfo('governor')

# %%
house_tr = ei_house.transform(house)
senate_tr = ei_senate.transform(senate)
governor_tr = ei_governor.transform(governor)

# %%
house_tr.head()
# Out:
#                                      race_name race_type state  \
# 0  pennsylvania 12th district special election     house    PA
# 1                   new hampshire 1st district     house    NH
# 2                   new hampshire 2nd district     house    NH
# 3                   new hampshire 1st district     house    NH
# 4                   new hampshire 2nd district     house    NH
#
#           top_candidates  pollster                           poll_results  \
# 0         [burns, critz]   ppp (d)         {'burns': 44.0, 'critz': 41.0}
# 1  [guinta, shea-porter]   ppp (d)  {'guinta': 46.0, 'shea-porter': 45.0}
# 2          [bass, swett]   ppp (d)          {'bass': 47.0, 'swett': 32.0}
# 3  [guinta, shea-porter]  wmur/unh  {'guinta': 42.0, 'shea-porter': 38.0}
# 4          [bass, swett]  wmur/unh          {'bass': 44.0, 'swett': 27.0}
#
#   poll_leader  poll_spread        date
# 0       burns          3.0  2010-04-20
# 1      guinta          1.0  2010-04-22
# 2        bass         15.0  2010-04-22
# 3      guinta          4.0  2010-04-30
# 4        bass         17.0  2010-04-30

# %%
senate_tr.head()
# Out:
#          race_name race_type state      top_candidates             pollster  \
# 0   florida senate    senate    FL      [crist, rubio]           quinnipiac
# 1  arkansas senate    senate    AR  [boozman, lincoln]  r2000/daily kos (d)
# 2  arkansas senate    senate    AR   [boozman, halter]  r2000/daily kos (d)
# 3   florida senate    senate    FL       [rubio, meek]           quinnipiac
# 4   florida senate    senate    FL      [rubio, crist]           quinnipiac
#
#                                    poll_results poll_leader  poll_spread  \
# 0  {'crist': 32.0, 'rubio': 30.0, 'meek': 24.0}       crist          2.0
# 1            {'boozman': 50.0, 'lincoln': 43.0}     boozman          7.0
# 2             {'boozman': 48.0, 'halter': 41.0}     boozman          7.0
# 3                 {'rubio': 42.0, 'meek': 38.0}       rubio          4.0
# 4                {'rubio': 56.0, 'crist': 33.0}       rubio         23.0
#
#          date
# 0  2010-04-15
# 1  2010-04-15
# 2  2010-04-15
# 3  2010-04-15
# 4  2010-04-15

# %%
governor_tr.head()
# Out:
#            race_name race_type state           top_candidates  \
# 0  colorado governor  governor    CO  [mcinnis, hickenlooper]
# 1   arizona governor  governor    AZ          [brewer, mills]
# 2  new york governor  governor    NY            [lazio, levy]
# 3  new york governor  governor    NY            [cuomo, levy]
# 4  new york governor  governor    NY           [cuomo, lazio]
#
#             pollster                                       poll_results  \
# 0  rasmussen reports            {'hickenlooper': 42.0, 'mcinnis': 48.0}
# 1  rasmussen reports  {'brewer': 26.0, 'mills': 18.0, 'martin': 12.0...
# 2              siena    {'lazio': 29.0, 'levy': 15.0, 'paladino': 13.0}
# 3              siena                      {'cuomo': 58.0, 'levy': 23.0}
# 4              siena                     {'cuomo': 61.0, 'lazio': 24.0}
#
#   poll_leader  poll_spread        date
# 0     mcinnis          6.0  2010-04-16
# 1      brewer          8.0  2010-04-17
# 2       lazio         14.0  2010-04-18
# 3       cuomo         35.0  2010-04-18
# 4       cuomo         37.0  2010-04-18

# %% [markdown]
# # [WIP] Add information from FiveThirtyEight pollster grades
#
# FiveThirtyEight publishes a list of pollster grades. We want to add this information to our poll data. First, a look at the pollster grades dataset:

# %%
pollster = pd.read_csv(DATA_DIR/'cleaned'/'pollster_grades_538.csv')
pollster.head()
# Out:
#                             Pollster 538 Grade
# 0                       Selzer & Co.        A+
# 1                Monmouth University        A+
# 2  Field Research Corp. (Field Poll)        A+
# 3           ABC News/Washington Post        A+
# 4                     Elway Research        A+

# %% [markdown]
# To match our transformed RCP data, we need to make sure that the pollsters are lowercased. Furthermore, RCP can have multiple pollsters for each line; in this case, we take the maximum of the pollster grades. (The reasoning: we figure that if a reputable organization (e.g. NYT) and a less-reputable organization (e.g. some_pollster) collaborate, NYT will likely make sure that it meets their standards of polling.)

# %%
class AddPollsterGrades(BaseEstimator, TransformerMixin):
    """
    Add pollster grades to already-cleaned Real Clear Politics polling data.
    
    Parameters
    ----------
    pollster_grades : filepath(str)
        File path to pollster grades (collected by FiveThirtyEight).
        
    grade_bins : dict
        Dictionary mapping grades to bins of choice. Keys must include:
        A+, A, A-, B+, B, B-, C+, C, C-, D+, D, D-, F, None
    """    
    def __init__(self, pollster_grades_filepath, grade_map=None):
        self.pollster_grades = pd.read_csv(pollster_grades_filepath)
        if grade_map == None:
            self.grade_map = {'A+':13, 'A':12, 'A-':11, 'B+':10, 'B':9, 'B-':8, 'C+':7, 
                              'C':6, 'C-':5, 'D+':4, 'D':3, 'D-':2, 'F':1}
        else:
            self.grade_map = grade_map
        
    def fit(self, X, y=None):       
        return self
            
    def transform(self, X, y=None):
        # Clean pollster grades
        self.pollster_grades['Pollster'] = (
            self.pollster_grades['Pollster']
            .str.lower()
            .str.replace('Public Policy Polling', 'PPP')
        )
        
        # Add pollster score from grade
        self.pollster_grades['score'] = self.pollster_grades['538 Grade'].map(self.grade_map)
        
        # Clean RCP polling data
        X['pollster'] = (
            X['pollster'].str.replace('\*', '')
            .str.replace('\s*[\(\[].*?[\)\]]\s*', '')
        )
        
        expanded_polls = X['pollster'].str.split('/', n=10, expand=True)
        
        
        
        
        return X

# %%
### CONG YANG
pollster = pd.read_csv(DATA_DIR/'cleaned'/'pollster_grades_538.csv')
pollster.head()
for i in range(0,len(pollster.iloc[:,0])):
    temp = pollster.iloc[i,0]
    temp = temp.replace('Public Policy Polling', 'PPP')
    if temp == 'PPP':
        pollster.iloc[i,0] = temp
pollster["score"] = np.nan
gradetoscore =pd.read_csv(DATA_DIR/'cleaned'/'gradetoscore.csv')
for i in range(0,len(pollster.iloc[:,0])):
    for j in range(0,len(gradetoscore)):
        if gradetoscore.iloc[j,0]==pollster.iloc[i,1]:
            pollster.iloc[i,2]=gradetoscore.iloc[j,1]

def aggregate(df,pollster):
    # select rcp poll column
    poll = pd.Series.to_frame(df['Poll'])
    
    # for each poll, remove \* and (\w*)
    for i in range (0,len(poll)):
        poll.iloc[i,0] = re.sub("\s*[\(\[].*?[\)\]]", '', poll.iloc[i,0])
        temp = poll.iloc[i,0]
        temp = temp.rstrip()
        poll.iloc[i,0] = temp
        temp = poll.iloc[i,0]
        temp = temp.replace("*","")
        poll.iloc[i,0] = temp
        
    # expand on /
    poll = poll['Poll'].str.split("/", n = 10, expand = True)
    df["score"] = np.nan
    # for each poll
    for i in range(0,len(poll.iloc[:,1])):
        max_score = 0
        temp_max = 0
        # iterate through each pollster
        for j in range(0,len(poll.iloc[1,:])):
            if poll.iloc[i,j] is None:
                break
            else:
                temp = pollster[pollster['Pollster'].str.contains(poll.iloc[i,j], case = False)]
                if len(temp)>0:
                    temp_max = max(temp['score'])
            if max_score < temp_max:
                max_score = temp_max
        df['score'].iloc[i] = max_score
    return df,poll

# %%
### CONG YANG
aggregate(RCP_c_approval.iloc[:],pollster)

# %% [markdown]
# # Temp code to get FEC downloads pipeline running

# %%
# (
#     pd.concat([house_tr, senate_tr, governor_tr])
#     .reset_index(drop=True)
#     .to_pickle(DATA_DIR/'tmp_for_nick.pkl')
# )

# %%
pd.read_pickle(DATA_DIR/'tmp_for_nick.pkl')
# Out:
#                                         race_name race_type state  \
# 0     pennsylvania 12th district special election     house    PA
# 1                      new hampshire 1st district     house    NH
# 2                      new hampshire 2nd district     house    NH
# 3                      new hampshire 1st district     house    NH
# 4                      new hampshire 2nd district     house    NH
# 5                           maryland 1st district     house    MD
# 6     pennsylvania 12th district special election     house    PA
# 7     pennsylvania 12th district special election     house    PA
# 8            hawaii 1st district special election     house    HI
# 9     pennsylvania 12th district special election     house    PA
# 10    pennsylvania 12th district special election     house    PA
# 11    pennsylvania 12th district special election     house    PA
# 12                    south carolina 4th district     house    SC
# 13                    north carolina 2nd district     house    NC
# 14                         minnesota 6th district     house    MN
# 15                            nevada 3rd district     house    NV
# 16                          virginia 5th district     house    VA
# 17                          virginia 9th district     house    VA
# 18                        new mexico 1st district     house    NM
# 19                          kentucky 6th district     house    KY
# 20                   north carolina 11th district     house    NC
# 21                            nevada 3rd district     house    NV
# 22                          virginia 5th district     house    VA
# 23                         new york 23rd district     house    NY
# 24                         new york 25th district     house    NY
# 25                      pennsylvania 3rd district     house    PA
# 26                     pennsylvania 10th district     house    PA
# 27                     pennsylvania 11th district     house    PA
# 28                     pennsylvania 12th district     house    PA
# 29                     west virginia 3rd district     house    WV
# ...                                           ...       ...   ...
# 6608                        pennsylvania governor  governor    PA
# 6609                           wisconsin governor  governor    WI
# 6610                              nevada governor  governor    NV
# 6611                                iowa governor  governor    IA
# 6612                          california governor  governor    CA
# 6613                             florida governor  governor    FL
# 6614                             arizona governor  governor    AZ
# 6615                            michigan governor  governor    MI
# 6616                            michigan governor  governor    MI
# 6617                              nevada governor  governor    NV
# 6618                             georgia governor  governor    GA
# 6619                             florida governor  governor    FL
# 6620                             florida governor  governor    FL
# 6621                            oklahoma governor  governor    OK
# 6622                          new mexico governor  governor    NM
# 6623                            new york governor  governor    NY
# 6624                             arizona governor  governor    AZ
# 6625                             florida governor  governor    FL
# 6626                          california governor  governor    CA
# 6627                       new hampshire governor  governor    NH
# 6628                            michigan governor  governor    MI
# 6629                             arizona governor  governor    AZ
# 6630                             arizona governor  governor    AZ
# 6631                        south dakota governor  governor    SD
# 6632                              nevada governor  governor    NV
# 6633                              nevada governor  governor    NV
# 6634                             florida governor  governor    FL
# 6635                             florida governor  governor    FL
# 6636                             florida governor  governor    FL
# 6637                             florida governor  governor    FL
#
#              top_candidates                  pollster  \
# 0            [burns, critz]                   ppp (d)
# 1     [guinta, shea-porter]                   ppp (d)
# 2             [bass, swett]                   ppp (d)
# 3     [guinta, shea-porter]                  wmur/unh
# 4             [bass, swett]                  wmur/unh
# 5        [harris, kratovil]                   pos (r)
# 6            [burns, critz]       r2000/daily kos (d)
# 7            [burns, critz]       r2000/daily kos (d)
# 8              [djou, case]       honolulu advertiser
# 9            [critz, burns]               susquehanna
# 10           [critz, burns]               susquehanna
# 11           [burns, critz]                   ppp (d)
# 12          [gowdy, inglis]                   ppp (d)
# 13     [ellmers, etheridge]                 surveyusa
# 14        [bachmann, clark]                 surveyusa
# 15            [titus, heck]  las vegas review-journal
# 16        [hurt, perriello]                 surveyusa
# 17      [boucher, griffith]                 surveyusa
# 18       [barela, heinrich]                 surveyusa
# 19         [chandler, barr]       cn|2/braun research
# 20         [shuler, miller]                 surveyusa
# 21            [titus, heck]  las vegas review-journal
# 22        [hurt, perriello]             aaf/ayers (r)
# 23          [owens, doheny]             aaf/ayers (r)
# 24        [maffei, buerkle]             aaf/ayers (r)
# 25      [kelly, dahlkemper]             aaf/ayers (r)
# 26         [marino, carney]             aaf/ayers (r)
# 27    [barletta, kanjorski]             aaf/ayers (r)
# 28           [burns, critz]             aaf/ayers (r)
# 29        [rahall, maynard]             aaf/ayers (r)
# ...                     ...                       ...
# 6608         [wolf, wagner]              morning call
# 6609        [evers, walker]                   emerson
# 6610      [laxalt, sisolak]       trafalgar group (r)
# 6611    [hubbell, reynolds]       des moines register
# 6612          [newsom, cox]           stanford/yougov
# 6613     [gillum, desantis]            st. pete polls
# 6614        [ducey, garcia]                   harrisx
# 6615    [whitmer, schuette]         mitchell research
# 6616    [whitmer, schuette]            target-insyght
# 6617      [laxalt, sisolak]                   harrisx
# 6618         [kemp, abrams]       trafalgar group (r)
# 6619     [gillum, desantis]                   harrisx
# 6620     [gillum, desantis]                    gravis
# 6621     [stitt, edmondson]              sooner poll*
# 6622      [grisham, pearce]       albuquerque journal
# 6623      [cuomo, molinaro]                    siena*
# 6624        [ducey, garcia]                    gravis
# 6625     [gillum, desantis]                quinnipiac
# 6626          [newsom, cox]            kabc/surveyusa
# 6627        [sununu, kelly]                      unh*
# 6628    [whitmer, schuette]         mitchell research
# 6629        [ducey, garcia]                   harrisx
# 6630        [ducey, garcia]                   emerson
# 6631         [noem, sutton]                   emerson
# 6632      [laxalt, sisolak]                   harrisx
# 6633      [sisolak, laxalt]                   emerson
# 6634     [gillum, desantis]                   harrisx
# 6635     [gillum, desantis]                   emerson
# 6636     [gillum, desantis]            st. pete polls
# 6637     [gillum, desantis]           nbc news/marist
#
#                                            poll_results poll_leader  \
# 0                        {'burns': 44.0, 'critz': 41.0}       burns
# 1                 {'guinta': 46.0, 'shea-porter': 45.0}      guinta
# 2                         {'bass': 47.0, 'swett': 32.0}        bass
# 3                 {'guinta': 42.0, 'shea-porter': 38.0}      guinta
# 4                         {'bass': 44.0, 'swett': 27.0}        bass
# 5                    {'harris': 39.0, 'kratovil': 36.0}      harris
# 6                        {'burns': 46.0, 'critz': 40.0}       burns
# 7                        {'critz': 40.0, 'burns': 46.0}       burns
# 8        {'djou': 36.0, 'case': 28.0, 'hanabusa': 22.0}        djou
# 9                        {'critz': 44.0, 'burns': 38.0}       critz
# 10                       {'burns': 38.0, 'critz': 44.0}       critz
# 11                       {'critz': 47.0, 'burns': 48.0}       burns
# 12    {'gowdy': 37.0, 'inglis': 33.0, 'lee': 9.0, 't...       gowdy
# 13    {'ellmers': 39.0, 'etheridge': 38.0, 'rose': 1...     ellmers
# 14    {'bachmann': 48.0, 'clark': 39.0, 'anderson': ...    bachmann
# 15                        {'titus': 42.0, 'heck': 40.0}       titus
# 16                    {'hurt': 58.0, 'perriello': 35.0}        hurt
# 17                  {'boucher': 52.0, 'griffith': 39.0}     boucher
# 18                   {'barela': 51.0, 'heinrich': 45.0}      barela
# 19                     {'chandler': 46.0, 'barr': 32.0}    chandler
# 20                     {'shuler': 45.0, 'miller': 44.0}      shuler
# 21                        {'titus': 43.0, 'heck': 42.0}       titus
# 22                    {'hurt': 49.0, 'perriello': 43.0}        hurt
# 23                      {'owens': 41.0, 'doheny': 39.0}       owens
# 24                    {'maffei': 44.0, 'buerkle': 41.0}      maffei
# 25                  {'kelly': 52.0, 'dahlkemper': 38.0}       kelly
# 26                     {'marino': 52.0, 'carney': 37.0}      marino
# 27                {'barletta': 52.0, 'kanjorski': 41.0}    barletta
# 28                       {'burns': 44.0, 'critz': 40.0}       burns
# 29                    {'rahall': 53.0, 'maynard': 37.0}      rahall
# ...                                                 ...         ...
# 6608                     {'wolf': 58.0, 'wagner': 37.0}        wolf
# 6609                    {'evers': 51.0, 'walker': 46.0}       evers
# 6610                  {'laxalt': 47.0, 'sisolak': 45.0}      laxalt
# 6611                {'hubbell': 46.0, 'reynolds': 44.0}     hubbell
# 6612                      {'newsom': 53.0, 'cox': 34.0}      newsom
# 6613                 {'gillum': 48.0, 'desantis': 46.0}      gillum
# 6614                    {'ducey': 56.0, 'garcia': 36.0}       ducey
# 6615                {'whitmer': 54.0, 'schuette': 40.0}     whitmer
# 6616                {'whitmer': 48.0, 'schuette': 44.0}     whitmer
# 6617                  {'laxalt': 45.0, 'sisolak': 44.0}      laxalt
# 6618                     {'kemp': 52.0, 'abrams': 40.0}        kemp
# 6619                 {'gillum': 48.0, 'desantis': 45.0}      gillum
# 6620                 {'gillum': 48.0, 'desantis': 47.0}      gillum
# 6621                 {'stitt': 47.0, 'edmondson': 44.0}       stitt
# 6622                  {'grisham': 53.0, 'pearce': 43.0}     grisham
# 6623                  {'cuomo': 49.0, 'molinaro': 36.0}       cuomo
# 6624                    {'ducey': 53.0, 'garcia': 40.0}       ducey
# 6625                 {'gillum': 50.0, 'desantis': 43.0}      gillum
# 6626                      {'newsom': 53.0, 'cox': 38.0}      newsom
# 6627                    {'sununu': 49.0, 'kelly': 49.0}         NaN
# 6628                {'whitmer': 48.0, 'schuette': 41.0}     whitmer
# 6629                    {'ducey': 56.0, 'garcia': 37.0}       ducey
# 6630                    {'ducey': 55.0, 'garcia': 40.0}       ducey
# 6631                     {'noem': 48.0, 'sutton': 47.0}        noem
# 6632                  {'laxalt': 45.0, 'sisolak': 44.0}      laxalt
# 6633                  {'laxalt': 47.0, 'sisolak': 48.0}     sisolak
# 6634                 {'gillum': 49.0, 'desantis': 45.0}      gillum
# 6635                 {'gillum': 51.0, 'desantis': 46.0}      gillum
# 6636                 {'gillum': 50.0, 'desantis': 45.0}      gillum
# 6637                 {'gillum': 50.0, 'desantis': 46.0}      gillum
#
#       poll_spread        date
# 0             3.0  2010-04-20
# 1             1.0  2010-04-22
# 2            15.0  2010-04-22
# 3             4.0  2010-04-30
# 4            17.0  2010-04-30
# 5             3.0  2010-05-01
# 6             6.0  2010-05-01
# 7             6.0  2010-05-01
# 8             8.0  2010-05-02
# 9             6.0  2010-05-12
# 10            6.0  2010-05-12
# 11            1.0  2010-05-17
# 12            4.0  2010-06-06
# 13            1.0  2010-06-17
# 14            9.0  2010-07-13
# 15            2.0  2010-07-18
# 16           23.0  2010-07-21
# 17           13.0  2010-07-22
# 18            6.0  2010-07-27
# 19           14.0  2010-07-29
# 20            1.0  2010-08-02
# 21            1.0  2010-08-15
# 22            6.0  2010-08-16
# 23            2.0  2010-08-16
# 24            3.0  2010-08-16
# 25           14.0  2010-08-16
# 26           15.0  2010-08-16
# 27           11.0  2010-08-16
# 28            4.0  2010-08-16
# 29           16.0  2010-08-16
# ...           ...         ...
# 6608         21.0  2018-11-02
# 6609          5.0  2018-11-02
# 6610          2.0  2018-11-03
# 6611          2.0  2018-11-03
# 6612         19.0  2018-11-03
# 6613          2.0  2018-11-03
# 6614         20.0  2018-11-04
# 6615         14.0  2018-11-04
# 6616          4.0  2018-11-04
# 6617          1.0  2018-11-04
# 6618         12.0  2018-11-04
# 6619          3.0  2018-11-04
# 6620          1.0  2018-11-04
# 6621          3.0  2018-11-04
# 6622         10.0  2018-11-04
# 6623         13.0  2018-11-04
# 6624         13.0  2018-11-05
# 6625          7.0  2018-11-05
# 6626         15.0  2018-11-05
# 6627          NaN  2018-11-05
# 6628          7.0  2018-11-05
# 6629         19.0  2018-11-05
# 6630         15.0  2018-11-05
# 6631          1.0  2018-11-05
# 6632          1.0  2018-11-05
# 6633          1.0  2018-11-05
# 6634          4.0  2018-11-05
# 6635          5.0  2018-11-05
# 6636          5.0  2018-11-05
# 6637          4.0  2018-11-05
#
# [6638 rows x 9 columns]

# %%
from_rcp = [
    'monmouth university',
    'abc news/wash post',
    'abc/wp',
    'abc news',
    'abc/wash post tracking',
    'abc news tracking',
    
]

# %%
to_rcp = [
    'monmouth',
    'abc news, wapo',
    'abc news, wapo',
    'abc news, wapo',
    'abc news, wapo',
    'abc news, wapo',
    
]

# %%
from_538 = [
    'selzer & co.',
    'monmouth university',
    'field research corp. (field poll)',
    'abc news/washington post',
]

# %%
to_538 = [
    'selzer',
    'monmouth',
    'field',
    'abc news, wapo',
]
