# %%
import pandas as pd
import numpy as np
from pathlib import Path
import bs4 as bs
import requests
import re
import unidecode
import us
from datetime import datetime, date as make_date

DATA_DIR = Path('.')/'..'/'..'/'data'
pd.set_option('display.max_rows', 500)

# %%
##### Map name:abbr for states
# Initial mapping
STATES_DICT = us.states.mapping('name', 'abbr')
# Remove all unwanted states
territories = ['American Samoa', 'Dakota', 'District of Columbia', 'Guam','Northern Mariana Islands', 
               'Orleans', 'Philippine Islands', 'Puerto Rico', 'Virgin Islands']
for t in territories:
    del STATES_DICT[t]

    
##### Map parties of interest; all others will be cast to NaN #####
PARTY_DICT = {'republican' : 'r', 'democratic' : 'd'}


##### Regex shortcuts #####
NAME = r"[\w\s\-\.\'\,]"

def clean_name(series):
    """
    Remove following punctuation commonly found in names: - . , '
    Also strip names of accents
    """
    result = series.copy()
    
    punc_list = ['-', '.', '\'', ',']
    for punc in punc_list:
        result = result.str.replace(punc, '')
    result = result.apply(unidecode.unidecode)
    
    return result

# %% [markdown]
# # House Names
#
# ### Names 2014, 2016, 2018

# %%
def scrape_house_names_new(year):
    """Works for 2014, 2016, 2018."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/{year}_United_States_House_of_Representatives_elections')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    # Initialize empty lists
    names = []
    parties = []
    race_types = []
    years = []
    states = []
    num_states = 0
    
    # TODO: Go through special elections as well, which are not sortable tables
    
    # iterate through all sortable tables
    for table in soup.find_all('table', class_="wikitable sortable"):
        # skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # each table is one state 
        state = None
        for tr in table.find_all('tr')[2:]:
            # find state if not set yet for this table
            if not state:
                state = re.match(r"([\w\s]+)\s.+", tr.find('th').text).groups()[0]
                num_states += 1
            
            # candidate names are stored in last cell of row
            candidates = tr.find_all('td')[-1]
            candidates_text = re.findall(rf"\w{NAME}+?\(\w+?\)", candidates.text)
            
            for candidate in candidates_text:
                matcher = re.match(rf"({NAME}+)\s\((\w+)\)", candidate.lower())
                # if valid match
                if matcher:
                    name, party = matcher.groups()
                    names.append(name)
                    parties.append(party)
                    race_types.append(RACE_TYPE)
                    years.append(year)
                    states.append(state)
                    
        # stop at 50 states
        if num_states == 50:
            break
    
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'year': years,
                       'state': states})
    df['name'] = clean_name(df['name'])
    df['state'] = df['state'].map(STATES_DICT)
    df = df.dropna(subset=['state'])
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_names_2014 = scrape_house_names_new(2014)
house_names_2016 = scrape_house_names_new(2016)
house_names_2018 = scrape_house_names_new(2018)

# %% [markdown]
# ### Names 2012

# %%
def scrape_house_names_2012():
    """Works for 2012."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/United_States_House_of_Representatives_elections,_2012')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    names = []
    parties = []
    race_types = []
    years = []
    states = []
    num_states = 0
    
    for table in soup.find_all('table', class_='wikitable')[3:]:
    #     print(table.prettify())
        state = None
        for tr in table.find_all('tr')[1:]:
            # find state if not set yet
            if not state:
                state = re.match(r"([\w\s]+)\s.+", tr.find('td').text).groups()[0]
                num_states += 1

            # find candidate names
            candidates = tr.find_all('td')[-1]
            candidates_text = re.findall(rf"\w{NAME}+?\(\w+?\)", candidates.text)
            for candidate in candidates_text:
                matcher = re.match(rf"({NAME}+)\s\((\w+)\)", candidate.lower())
                if matcher:
                    name, party = matcher.groups()
                    names.append(name)
                    parties.append(party)
                    race_types.append(RACE_TYPE)
                    years.append(2012)
                    states.append(state)
                    
        if num_states == 50:
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'year': years,
                       'state': states})
    df['name'] = clean_name(df['name'])
    df['state'] = df['state'].map(STATES_DICT)
    df = df.dropna(subset=['state'])
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_names_2012 = scrape_house_names_2012()

# %% [markdown]
# ### Names 2010

# %%
def scrape_house_names_2010():
    """Works for 2010."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/United_States_House_of_Representatives_elections,_2010')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    names = []
    parties = []
    race_types = []
    years = []
    states = []
    num_states = 0
    
    for table in soup.find_all('table', class_='wikitable')[4:]:
        state = None
        for tr in table.find_all('tr')[1:]:
            if not state:
                state = re.match(r"([\w\s]+)\s.+", tr.find('th').text).groups()[0]
                num_states += 1

            # find candidate names
            candidates = tr.find_all('td')[-1]
            candidates_text = re.findall(rf"\w{NAME}+?\(\w+?\)", candidates.text)
            for candidate in candidates_text:
                matcher = re.match(rf"({NAME}+)\s\((\w+)\)", candidate.lower())
                if matcher:
                    name, party = matcher.groups()
                    names.append(name)
                    parties.append(party)
                    race_types.append(RACE_TYPE)
                    years.append(2010)
                    states.append(state)
                    
        if num_states == 50:
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'year': years,
                       'state': states})
    df['name'] = clean_name(df['name'])
    df['state'] = df['state'].map(STATES_DICT)
    df = df.dropna(subset=['state'])
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_names_2010 = scrape_house_names_2010()

# %% [markdown]
# ### House Concatenate

# %%
house_names = pd.concat([house_names_2010, house_names_2012, house_names_2014, house_names_2016, house_names_2018],
                       ignore_index=True)

# %%
print('Shape:', house_names.shape)
print('\nNull values:')
print(house_names.isnull().sum())
house_names
# Out:
# Shape: (5595, 5)
#
# Null values:
# name         0
# party        0
# race_type    0
# year         0
# state        0
# dtype: int64
#                           name party race_type  year state
# 0                    jo bonner     o     house  2010    AL
# 1                 david walter     o     house  2010    AL
# 2                  martha roby     o     house  2010    AL
# 3                 bobby bright     o     house  2010    AL
# 4                  mike rogers     o     house  2010    AL
# 5                steve segrest     o     house  2010    AL
# 6              robert aderholt     o     house  2010    AL
# 7                    mo brooks     o     house  2010    AL
# 8                   steve raby     o     house  2010    AL
# 9               spencer bachus     o     house  2010    AL
# 10                terri sewell     o     house  2010    AL
# 11             don chamberlain     o     house  2010    AL
# 12                   don young     o     house  2010    AK
# 13              harry crawford     o     house  2010    AK
# 14                  paul gosar     o     house  2010    AZ
# 15             ann kirkpatrick     o     house  2010    AZ
# 16                nicole patti     o     house  2010    AZ
# 17                trent franks     o     house  2010    AZ
# 18               john thrasher     o     house  2010    AZ
# 19              powell gammill     o     house  2010    AZ
# 20                  ben quayle     o     house  2010    AZ
# 21                 jon hulburd     o     house  2010    AZ
# 22               michael shoen     o     house  2010    AZ
# 23               leonard clark     o     house  2010    AZ
# 24                   ed pastor     o     house  2010    AZ
# 25             janet contreras     o     house  2010    AZ
# 26                    joe cobb     o     house  2010    AZ
# 27              rebecca dewitt     o     house  2010    AZ
# 28            david schweikert     o     house  2010    AZ
# 29              harry mitchell     o     house  2010    AZ
# 30                  nick coons     o     house  2010    AZ
# 31                  jeff flake     o     house  2010    AZ
# 32           rebecca schneider     o     house  2010    AZ
# 33             richard grayson     o     house  2010    AZ
# 34                 darell tapp     o     house  2010    AZ
# 35               raul grijalva     o     house  2010    AZ
# 36                ruth mcclung     o     house  2010    AZ
# 37                harley meyer     o     house  2010    AZ
# 38                george keane     o     house  2010    AZ
# 39          gabrielle giffords     o     house  2010    AZ
# 40                 jesse kelly     o     house  2010    AZ
# 41               steven stoltz     o     house  2010    AZ
# 42               rick crawford     o     house  2010    AR
# 43                 chad causey     o     house  2010    AR
# 44                   ken adler     o     house  2010    AR
# 45                 tim griffin     o     house  2010    AR
# 46               joyce elliott     o     house  2010    AR
# 47                  lance levi     o     house  2010    AR
# 48               lewis kennedy     o     house  2010    AR
# 49                steve womack     o     house  2010    AR
# 50              david whitaker     o     house  2010    AR
# 51                   mike ross     o     house  2010    AR
# 52            beth anne rankin     o     house  2010    AR
# 53                joshua drake     o     house  2010    AR
# 54               mike thompson     o     house  2010    CA
# 55                 loren hanks     o     house  2010    CA
# 56                carol wolman     o     house  2010    CA
# 57              mike rodrigues     o     house  2010    CA
# 58                wally herger     o     house  2010    CA
# 59                    jim reed     o     house  2010    CA
# 60                 dan lungren     o     house  2010    CA
# 61                    ami bera     o     house  2010    CA
# 62             jerry leidecker     o     house  2010    CA
# 63         douglas arthur tuma     o     house  2010    CA
# 64                 mike roskey     o     house  2010    CA
# 65              tom mcclintock     o     house  2010    CA
# 66                clint curtis     o     house  2010    CA
# 67                   ben emery     o     house  2010    CA
# 68                doris matsui     o     house  2010    CA
# 69                  paul smith     o     house  2010    CA
# 70          gerald allen frink     o     house  2010    CA
# 71                lynn woolsey     o     house  2010    CA
# 72                    jim judd     o     house  2010    CA
# 73                eugene ruyle     o     house  2010    CA
# 148               wayne miller     o     house  2010    CA
# 149              maxine waters     o     house  2010    CA
# 150                bruce brown     o     house  2010    CA
# 151                jane harman     o     house  2010    CA
# 152                mattie fein     o     house  2010    CA
# 153                herb peters     o     house  2010    CA
# 154           laura richardson     o     house  2010    CA
# 155                star parker     o     house  2010    CA
# 156              nicholas dibs     o     house  2010    CA
# 157           grace napolitano     o     house  2010    CA
# 158              robert vaughn     o     house  2010    CA
# 159              linda sanchez     o     house  2010    CA
# 160                larry andre     o     house  2010    CA
# 161                 john smith     o     house  2010    CA
# 162                   ed royce     o     house  2010    CA
# 163           christina avalos     o     house  2010    CA
# 164                jerry lewis     o     house  2010    CA
# 165                pat meagher     o     house  2010    CA
# 166                gary miller     o     house  2010    CA
# 167         michael williamson     o     house  2010    CA
# 168               mark lambert     o     house  2010    CA
# 169                   joe baca     o     house  2010    CA
# 170              scott folkens     o     house  2010    CA
# 171                ken calvert     o     house  2010    CA
# 172               bill hedrick     o     house  2010    CA
# 173             mary bono mack     o     house  2010    CA
# 174              steve pougnet     o     house  2010    CA
# 175           bill lussenheide     o     house  2010    CA
# 176           dana rohrabacher     o     house  2010    CA
# 177                 ken arnold     o     house  2010    CA
# 178            loretta sanchez     o     house  2010    CA
# 179                   van tran     o     house  2010    CA
# 180              ceci iglesias     o     house  2010    CA
# 181              john campbell     o     house  2010    CA
# 182                  beth krom     o     house  2010    CA
# 183               mike binkley     o     house  2010    CA
# 184               darrell issa     o     house  2010    CA
# 185                howard katz     o     house  2010    CA
# 186                 dion clark     o     house  2010    CA
# 187                mike paster     o     house  2010    CA
# 188              brian bilbray     o     house  2010    CA
# 189             francine busby     o     house  2010    CA
# 190             lars grossmith     o     house  2010    CA
# 191               miriam clark     o     house  2010    CA
# 192                 bob filner     o     house  2010    CA
# 193             nick popaditch     o     house  2010    CA
# 194            duncan d hunter     o     house  2010    CA
# 195                   ray lutz     o     house  2010    CA
# 196             michael benoit     o     house  2010    CA
# 197                susan davis     o     house  2010    CA
# 198           michael crimmins     o     house  2010    CA
# 199                paul dekker     o     house  2010    CA
# 200              diana degette     o     house  2010    CO
# 201                mike fallon     o     house  2010    CO
# 202                 gary swing     o     house  2010    CO
# 203                clint jones     o     house  2010    CO
# 204              chris styskal     o     house  2010    CO
# 205                jared polis     o     house  2010    CO
# 206             stephen bailey     o     house  2010    CO
# 207                 jenna goss     o     house  2010    CO
# 208              curtis harris     o     house  2010    CO
# 209               scott tipton     o     house  2010    CO
# 210               john salazar     o     house  2010    CO
# 211             gregory gilman     o     house  2010    CO
# 212               jake segrest     o     house  2010    CO
# 213               cory gardner     o     house  2010    CO
# 214               betsy markey     o     house  2010    CO
# 215                  doug aden     o     house  2010    CO
# 216             ken waskiewicz     o     house  2010    CO
# 217               doug lamborn     o     house  2010    CO
# 218              kevin bradley     o     house  2010    CO
# 219                brian scott     o     house  2010    CO
# 220             jerrell klaver     o     house  2010    CO
# 221               mike coffman     o     house  2010    CO
# 222              john flerlage     o     house  2010    CO
# 223                rob mcnealy     o     house  2010    CO
# 224              ed perlmutter     o     house  2010    CO
# 225               ryan frazier     o     house  2010    CO
# 226                buck bailey     o     house  2010    CO
# 227                john larson     o     house  2010    CT
# 228               ann brickley     o     house  2010    CT
# 229           kenneth krayeske     o     house  2010    CT
# 230     christopher hutchinson     o     house  2010    CT
# 231               joe courtney     o     house  2010    CT
# 232          janet peckinpaugh     o     house  2010    CT
# 233              scott deshefy     o     house  2010    CT
# 234               rosa delauro     o     house  2010    CT
# 235             larry labriola     o     house  2010    CT
# 236          charles pillsbury     o     house  2010    CT
# 237                  jim himes     o     house  2010    CT
# 238              dan debicella     o     house  2010    CT
# 239               chris murphy     o     house  2010    CT
# 240              sam caligiuri     o     house  2010    CT
# 241                john carney     o     house  2010    DE
# 242              glen urquhart     o     house  2010    DE
# 243               earl lofland     o     house  2010    DE
# 244               brent wangen     o     house  2010    DE
# 245              jeffrey brown     o     house  2010    DE
# 246                jeff miller     o     house  2010    FL
# 247               joe cantrell     o     house  2010    FL
# 248                john krause     o     house  2010    FL
# 249          steve southerland     o     house  2010    FL
# ...                        ...   ...       ...   ...   ...
# 5345           david cicilline     d     house  2018    RI
# 5346           patrick donovan     r     house  2018    RI
# 5347   daniel joseph guilmette     o     house  2018    RI
# 5348            james langevin     d     house  2018    RI
# 5349               sal caiozzo     r     house  2018    RI
# 5350            joe cunningham     d     house  2018    SC
# 5351           katie arrington     r     house  2018    SC
# 5352                joe wilson     r     house  2018    SC
# 5353             sean carrigan     d     house  2018    SC
# 5354              sonny narang     o     house  2018    SC
# 5355               jeff duncan     r     house  2018    SC
# 5356                mary geren     d     house  2018    SC
# 5357                dave moore     o     house  2018    SC
# 5358           william timmons     r     house  2018    SC
# 5359             brandon brown     d     house  2018    SC
# 5360                 guy furay     o     house  2018    SC
# 5361              ralph norman     r     house  2018    SC
# 5362            archie parnell     d     house  2018    SC
# 5363          michael chandler     o     house  2018    SC
# 5364               jim clyburn     d     house  2018    SC
# 5365         gerhard gressmann     r     house  2018    SC
# 5366                bryan pugh     o     house  2018    SC
# 5367                  tom rice     r     house  2018    SC
# 5368           robert williams     d     house  2018    SC
# 5369           dick withington     o     house  2018    SC
# 5370             dusty johnson     r     house  2018    SD
# 5371              tim bjorkman     d     house  2018    SD
# 5372             ron wieczorek     o     house  2018    SD
# 5373        george hendrickson     o     house  2018    SD
# 5374                  phil roe     r     house  2018    TN
# 5375               marty olsen     d     house  2018    TN
# 5376            michael salyer     o     house  2018    TN
# 5377              tim burchett     r     house  2018    TN
# 5378               renee hoyos     d     house  2018    TN
# 5379              greg samples     o     house  2018    TN
# 5380               allen smith     o     house  2018    TN
# 5381             marc whitmire     o     house  2018    TN
# 5382            jeffrey grunau     o     house  2018    TN
# 5383         chuck fleischmann     r     house  2018    TN
# 5384         danielle mitchell     d     house  2018    TN
# 5385                rick tyler     o     house  2018    TN
# 5386          scott desjarlais     r     house  2018    TN
# 5387           mariah phillips     d     house  2018    TN
# 5388             michael shupe     o     house  2018    TN
# 5389                jim cooper     d     house  2018    TN
    source = requests.get(f'https://en.wikipedia.org/wiki/{year}_United_States_House_of_Representatives_elections')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    # Initialize empty lists
    names = []
    parties = []
    race_types = []
    dates = []
    states = []
    districts = []
    incumbents = []
    incumbent_first_electeds = []
    winners = []
    pcts = []
    
    ##### Special elections
    for table in soup.find_all('table', class_="wikitable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # Go through each row; non-sortable has one header row
        for tr in table.find_all('tr')[1:]:          
            cells = tr.find_all('td')
            
            # Extract state, district
            state, district = re.match(r"([\w\s]+)\s(.+)", cells[0].text).groups()
            if district == 'at-large':
                district = 0
            # Find incumbent name, elected year, and special election date
            incumbent = cells[1].text.lower().strip()
            incumbent_first_elected = cells[3].text.strip()
            date = re.match(r".*New member elected (.*?)\..*", cells[4].text).groups()[0]
            date = datetime.strptime(date, "%B %d, %Y")
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        # Stop after one table (since there's only one table of special elections)
        break

    ##### Regular elections
    for table in soup.find_all('table', class_="wikitable sortable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # Go through each row; sortable has two header rows
        for tr in table.find_all('tr')[2:]:
            # For these tables, state info is stored as 'th'. 
            # There is an edge case in which row_head does not exist; use previous state.
            row_head = tr.find('th')
            if row_head:
                state, district = re.match(r"([\w\s]+)\s(.+)", row_head.text).groups()
                if district == 'at-large':
                    district = 0
            
            cells = tr.find_all('td')
            if len(cells) < 6:
                incumbent = 'nope'
                incumbent_first_elected = np.nan
            else:
                # Find incumbent name, elected year, and special election date
                incumbent = cells[1].text.lower().strip()
                incumbent_first_elected = re.match(r"(\d*).*", cells[3].text.strip()).groups()[0]
            date = make_date(year, month, day)
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        if state == 'Wyoming':
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'date': dates,
                       'state': states,
                       'district': districts,
                       'incumbent': incumbents,
                       'incumbent_first_elected': incumbent_first_electeds,
                       'pct': pcts})
    df['name'] = clean_name(df['name'])
    df['incumbent'] = clean_name(df['incumbent'])
    df['incumbent'] = df['incumbent'].replace('nope', np.nan)
    df['state'] = df['state'].apply(unidecode.unidecode)
    df['state'] = df['state'].map(STATES_DICT)
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_2018 = scrape_house_2018(2018)
house_2016 = scrape_house_2016(2016)

# %%
def scrape_house_2014():
    """Works for 2014."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/2014_United_States_House_of_Representatives_elections')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    # Initialize empty lists
    names = []
    parties = []
    race_types = []
    dates = []
    states = []
    districts = []
    incumbents = []
    incumbent_first_electeds = []
    winners = []
    pcts = []
    
    ##### Special elections
    for table in soup.find_all('table', class_="wikitable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # Go through each row; non-sortable has one header row
        for tr in table.find_all('tr')[2:]:          
            cells = tr.find_all('td')
            
            # Extract state, district
            state, district = re.match(r"([\w\s]+)\s(.+)", cells[0].text).groups()
            if district == 'at-large':
                district = 0
            # Find incumbent name, elected year, and special election date
            incumbent = cells[1].text.lower().strip()
            incumbent_first_elected = re.match(r"(\d*).*", cells[3].text.strip()).groups()[0]
            date = re.match(r".*New member elected (.*?)\..*", cells[4].text).groups()[0]
            date = datetime.strptime(date, "%B %d, %Y")
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        # Stop after one table (since there's only one table of special elections)
        break

    ##### Regular elections
    for table in soup.find_all('table', class_="wikitable sortable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # Go through each row; sortable has two header rows
        for tr in table.find_all('tr')[2:]:
            # For these tables, state info is stored as 'th'. 
            # There is an edge case in which row_head does not exist; use previous state.
            row_head = tr.find('th')
            if row_head:
                state, district = re.match(r"([\w\s]+)\s(.+)", row_head.text).groups()
                if district == 'at-large':
                    district = 0
            
            if len(cells) < 6:
                incumbent = 'nope'
                incumbent_first_elected = np.nan
            else:
                # Find incumbent name, elected year, and special election date
                incumbent = cells[1].text.lower().strip()
                incumbent_first_elected = re.match(r"(\d*).*", cells[3].text.strip()).groups()[0]
            date = make_date(2014, 11, 4)
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        if state == 'Wyoming':
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'date': dates,
                       'state': states,
                       'district': districts,
                       'incumbent': incumbents,
                       'incumbent_first_elected': incumbent_first_electeds,
                       'pct': pcts})
    df['name'] = clean_name(df['name'])
    df['incumbent'] = clean_name(df['incumbent'])
    df['state'] = df['state'].apply(unidecode.unidecode)
    df['state'] = df['state'].map(STATES_DICT)
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_2014 = scrape_house_2014()

# %%
def scrape_house_2012():
    """Works for 2012."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/2012_United_States_House_of_Representatives_elections')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    # Initialize empty lists
    names = []
    parties = []
    race_types = []
    dates = []
    states = []
    districts = []
    incumbents = []
    incumbent_first_electeds = []
    winners = []
    pcts = []
    
    ##### Special elections
    for table in soup.find_all('table', class_="wikitable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        
        # Go through each row; non-sortable has one header row
        for tr in table.find_all('tr')[2:]:          
            cells = tr.find_all('td')
            
            # Extract state, district
            state, district = re.match(r"([\w\s]+)\s(.+)", cells[0].text).groups()
            if district == 'at-large':
                district = 0
            # Find incumbent name, elected year, and special election date
            incumbent = cells[1].text.lower().strip()
            incumbent_first_elected = re.match(r"(\d*).*", cells[3].text.strip()).groups()[0]
            date = re.match(r".*New member elected (.*?)\..*", cells[4].text).groups()[0]
            date = datetime.strptime(date, "%B %d, %Y")
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        # Stop after one table (since there's only one table of special elections)
        break

    ##### Regular elections
    special_passed = False
    for table in soup.find_all('table', class_="wikitable"):
        # Skip tables without candidate info
        if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
            continue
        special_passed = True
        if not special_passed:
            continue
        
        # Go through each row; sortable has two header rows
        for tr in table.find_all('tr')[2:]:
            # For these tables, state info is stored as 'th'. 
            # There is an edge case in which row_head does not exist; use previous state.
            row_head = tr.find('td')
            if row_head:
                state, district = re.match(r"([\w\s]+)\s(.+)", row_head.text).groups()
                if district == 'at-large':
                    district = 0
            
            cells = tr.find_all('td')
            if len(cells) < 6:
                state = 'nope'
                district = np.nan
                incumbent = 'nope'
                incumbent_first_elected = np.nan
            else:
                # Find incumbent name, elected year, and special election date
                incumbent = cells[-4].text.lower().strip()
                incumbent_first_elected = re.match(r"(\d*).*", cells[-3].text.strip()).groups()[0]
            date = make_date(2012, 11, 6)
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        if state == 'Wyoming':
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'date': dates,
                       'state': states,
                       'district': districts,
                       'incumbent': incumbents,
                       'incumbent_first_elected': incumbent_first_electeds,
                       'pct': pcts})
    df['name'] = clean_name(df['name'])
    df['incumbent'] = clean_name(df['incumbent'])
    df['incumbent'] = df['incumbent'].replace('nope', np.nan)
    df['state'] = df['state'].apply(unidecode.unidecode)
    df['state'] = df['state'].map(STATES_DICT)
    df['state'] = df['state'].replace('nope', np.nan)
    df['party'] = df['party'].map(PARTY_DICT)
    df.loc[df['party'].isnull(), 'party'] = 'o'
    
    return df

# %%
house_2012 = scrape_house_2012()

# %%
def scrape_house_2010():
    """Works for 2010."""
    RACE_TYPE = 'house'
    source = requests.get(f'https://en.wikipedia.org/wiki/2010_United_States_House_of_Representatives_elections')
    soup = bs.BeautifulSoup(source.content, features='html.parser')
    
    # Initialize empty lists
    names = []
    parties = []
    race_types = []
    dates = []
    states = []
    districts = []
    incumbents = []
    incumbent_first_electeds = []
    winners = []
    pcts = []
    
    ##### Special elections
#     for table in soup.find_all('table', class_="wikitable"):
#         # Skip tables without candidate info
#         if 'Candidates' not in [h.text.strip() for h in table.find_all('th', text=True)]:
#             continue
        
#         # Go through each row; non-sortable has one header row
#         for tr in table.find_all('tr')[2:]:          
#             cells = tr.find_all('td')
            
#             # Extract state, district
#             state, district = re.match(r"([\w\s]+)\s(.+)", cells[0].text).groups()
#             if district == 'at-large':
#                 district = 0
#             # Find incumbent name, elected year, and special election date
#             incumbent = cells[1].text.lower().strip()
#             incumbent_first_elected = re.match(r"(\d*).*", cells[3].text.strip()).groups()[0]
#             date = re.match(r".*New member elected (.*?)\..*", cells[4].text).groups()[0]
#             date = datetime.strptime(date, "%B %d, %Y")
            
#             # All candidate info stored in last cell
#             candidates = cells[-1]
#             candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
#             # Go through each candidate
#             for candidate in candidates_text:
#                 # Match name, party, pct. If pct missing, assign NaN
#                 name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
#                 if pct == '':
#                     pct = np.nan
#                 names.append(name)
#                 parties.append(party)
#                 race_types.append(RACE_TYPE)
#                 dates.append(date)
#                 states.append(state)
#                 districts.append(district)
#                 incumbents.append(incumbent)
#                 incumbent_first_electeds.append(incumbent_first_elected)
#                 pcts.append(pct)
#         # Stop after one table (since there's only one table of special elections)
#         break

    ##### Regular elections
    for table in soup.find_all('table', class_="wikitable")[4:]:        
        # Go through each row; sortable has two header rows
        for tr in table.find_all('tr')[1:]:
            # For these tables, state info is stored as 'th'. 
            # There is an edge case in which row_head does not exist; use previous state.
            row_head = tr.find('th')
            if row_head:
                state, district = re.match(r"([\w\s]+)\s(.+)", row_head.text).groups()
                if district == 'at-large':
                    district = 0
            
            cells = tr.find_all('td')
            if len(cells) < 5:
                state = 'nope'
                district = np.nan
                incumbent = 'nope'
                incumbent_first_elected = np.nan
            else:
                # Find incumbent name, elected year, and special election date
                incumbent = cells[-4].text.lower().strip()
                incumbent_first_elected = re.match(r"(\d*).*", cells[-3].text.strip()).groups()[0]
            date = make_date(2010, 11, 2)
            
            # All candidate info stored in last cell
            candidates = cells[-1]
            candidates_text = re.findall(rf"\s*{NAME}+\s\(\w+?\)\s*[\d\.]*", candidates.text)
            # Go through each candidate
            for candidate in candidates_text:
                # Match name, party, pct. If pct missing, assign NaN
                name, party, pct = re.match(rf"\s*({NAME}+)\s\((\w+?)\)\s*([\d\.]*)", candidate.lower()).groups()
                if pct == '':
                    pct = np.nan
                names.append(name)
                parties.append(party)
                race_types.append(RACE_TYPE)
                dates.append(date)
                states.append(state)
                districts.append(district)
                incumbents.append(incumbent)
                incumbent_first_electeds.append(incumbent_first_elected)
                pcts.append(pct)
        if state == 'Wyoming':
            break
        
    # return df
    df = pd.DataFrame({'name': names, 
                       'party': parties,
                       'race_type': race_types,
                       'date': dates,
                       'state': states,
                       'district': districts,
                       'incumbent': incumbents,
                       'incumbent_first_elected': incumbent_first_electeds,
                       'pct': pcts})
    df['name'] = clean_name(df['name'])
    df['incumbent'] = clean_name(df['incumbent'])
    df['incumbent'] = df['incumbent'].replace('nope', np.nan)
    df['state'] = df['state'].apply(unidecode.unidecode)
    df['state'] = df['state'].map(STATES_DICT)
    df['state'] = df['state'].replace('nope', np.nan)
    df['party'] = df['party'].str.lower()
    df.loc[~df['party'].isin(['d', 'r']), 'party'] = 'o'
    
    return df

# %%
house_2010 = scrape_house_2010()

# %%
house_2010
# Out:
#                            name party race_type        date state district  \
# 0                     jo bonner     r     house  2010-11-02    AL        1
# 1                  david walter     o     house  2010-11-02    AL        1
# 2                   martha roby     r     house  2010-11-02    AL        2
# 3                  bobby bright     d     house  2010-11-02    AL        2
# 4                   mike rogers     r     house  2010-11-02    AL        3
# 5                 steve segrest     d     house  2010-11-02    AL        3
# 6               robert aderholt     r     house  2010-11-02    AL        4
# 7                     mo brooks     r     house  2010-11-02    AL        5
# 8                    steve raby     d     house  2010-11-02    AL        5
# 9                spencer bachus     r     house  2010-11-02    AL        6
# 10                 terri sewell     d     house  2010-11-02    AL        7
# 11              don chamberlain     r     house  2010-11-02    AL        7
# 12                    don young     r     house  2010-11-02    AK        0
# 13               harry crawford     d     house  2010-11-02    AK        0
# 14                   paul gosar     r     house  2010-11-02    AZ        1
# 15              ann kirkpatrick     d     house  2010-11-02    AZ        1
# 16                 nicole patti     o     house  2010-11-02    AZ        1
# 17                 trent franks     r     house  2010-11-02    AZ        2
# 18                john thrasher     d     house  2010-11-02    AZ        2
# 19               powell gammill     o     house  2010-11-02    AZ        2
# 20                   ben quayle     r     house  2010-11-02    AZ        3
# 21                  jon hulburd     d     house  2010-11-02    AZ        3
# 22                michael shoen     o     house  2010-11-02    AZ        3
# 23                leonard clark     o     house  2010-11-02    AZ        3
# 24                    ed pastor     d     house  2010-11-02    AZ        4
# 25              janet contreras     r     house  2010-11-02    AZ        4
# 26                     joe cobb     o     house  2010-11-02    AZ        4
# 27               rebecca dewitt     o     house  2010-11-02    AZ        4
# 28             david schweikert     r     house  2010-11-02    AZ        5
# 29               harry mitchell     d     house  2010-11-02    AZ        5
# 30                   nick coons     o     house  2010-11-02    AZ        5
# 31                   jeff flake     r     house  2010-11-02    AZ        6
# 32            rebecca schneider     d     house  2010-11-02    AZ        6
# 33              richard grayson     o     house  2010-11-02    AZ        6
# 34                  darell tapp     o     house  2010-11-02    AZ        6
# 35                raul grijalva     d     house  2010-11-02    AZ        7
# 36                 ruth mcclung     r     house  2010-11-02    AZ        7
# 37                 harley meyer     o     house  2010-11-02    AZ        7
# 38                 george keane     o     house  2010-11-02    AZ        7
# 39           gabrielle giffords     d     house  2010-11-02    AZ        8
# 40                  jesse kelly     r     house  2010-11-02    AZ        8
# 41                steven stoltz     o     house  2010-11-02    AZ        8
# 42                rick crawford     r     house  2010-11-02    AR        1
# 43                  chad causey     d     house  2010-11-02    AR        1
# 44                    ken adler     o     house  2010-11-02    AR        1
# 45                  tim griffin     r     house  2010-11-02    AR        2
# 46                joyce elliott     d     house  2010-11-02    AR        2
# 47                   lance levi     o     house  2010-11-02    AR        2
# 48                lewis kennedy     o     house  2010-11-02    AR        2
# 49                 steve womack     r     house  2010-11-02    AR        3
# 1254  republican                    2000  68.5
# 1255  republican                    2000  29.7
# 1256  republican                    2000   1.8
# 1257  democratic                    1976  56.0
# 1258  democratic                    1976  44.0
# 1259  republican                    1998  68.2
# 1260  republican                    1998  30.1
# 1261  republican                    1998   1.6
# 1262  democratic                    1998  61.8
# 1263  democratic                    1998  38.2
# 1264  democratic                    1996  50.3
# 1265  democratic                    1996  46.5
# 1266  democratic                    1996   3.2
# 1267  democratic                    2004  69.0
# 1268  democratic                    2004  29.6
# 1269  democratic                    2004   1.4
# 1270  republican                    1978  69.3
# 1271  republican                    1978  27.4
# 1272  republican                    1978   3.3
# 1273  republican                    1979  70.7
# 1274  republican                    1979  29.3
# 1275  democratic                    1969  52.1
# 1276  democratic                    1969  44.4
# 1277  democratic                    1969   3.3
# 1278  democratic                    2006  54.8
# 1279  democratic                    2006  45.1
# 1280  republican                    2008  70.5
# 1281  republican                    2008  24.5
# 1282  republican                    2008   5.0
#
# [1283 rows x 9 columns]

# %%
house = pd.concat([house_2018, house_2016, house_2014, house_2012, house_2010], 
                 ignore_index=True)
house['winner'] = house['name'] == house['incumbent']

# %%
house
# Out:
#                            name party race_type                 date state  \
# 0                    conor lamb     d     house  2018-03-13 00:00:00    PA
# 1                  rick saccone     r     house  2018-03-13 00:00:00    PA
# 2                   drew miller     o     house  2018-03-13 00:00:00    PA
# 3                  debbie lesko     r     house  2018-04-24 00:00:00    AZ
# 4               hiral tipirneni     d     house  2018-04-24 00:00:00    AZ
# 5                 michael cloud     r     house  2018-06-30 00:00:00    TX
# 6                  eric holguin     d     house  2018-06-30 00:00:00    TX
# 7                   roy barrera     d     house  2018-06-30 00:00:00    TX
# 8                    bech bruun     r     house  2018-06-30 00:00:00    TX
# 9               mike westergren     d     house  2018-06-30 00:00:00    TX
# 10                  marty perez     r     house  2018-06-30 00:00:00    TX
# 11              judith cutright     o     house  2018-06-30 00:00:00    TX
# 12                 daniel tinus     o     house  2018-06-30 00:00:00    TX
# 13           christopher suprun     o     house  2018-06-30 00:00:00    TX
# 14               troy balderson     r     house  2018-08-07 00:00:00    OH
# 15                danny oconnor     d     house  2018-08-07 00:00:00    OH
# 16                  joe manchik     o     house  2018-08-07 00:00:00    OH
# 17                 brenda jones     d     house  2018-11-06 00:00:00    MI
# 18                  joe morelle     d     house  2018-11-06 00:00:00    NY
# 19                  jim maxwell     r     house  2018-11-06 00:00:00    NY
# 20             mary gay scanlon     d     house  2018-11-06 00:00:00    PA
# 21                    pearl kim     r     house  2018-11-06 00:00:00    PA
# 22              marty nothstein     r     house  2018-11-06 00:00:00    PA
# 23                   susan wild     d     house  2018-11-06 00:00:00    PA
# 24                bradley byrne     r     house  2018-11-06 00:00:00    AL
# 25            robert kennedy jr     d     house  2018-11-06 00:00:00    AL
# 26                  martha roby     r     house  2018-11-06 00:00:00    AL
# 27                tabitha isner     d     house  2018-11-06 00:00:00    AL
# 28                  mike rogers     r     house  2018-11-06 00:00:00    AL
# 29                mallory hagan     d     house  2018-11-06 00:00:00    AL
# 22         15              charlie dent                    2004   NaN   False
# 23         15              charlie dent                    2004   NaN   False
# 24          1             bradley byrne                    2013  63.3    True
# 25          1             bradley byrne                    2013  36.7   False
# 26          2               martha roby                    2010  61.5    True
# 27          2               martha roby                    2010  38.5   False
# 28          3               mike rogers                    2002  63.8    True
# 29          3               mike rogers                    2002  36.2   False
# 30          4           robert aderholt                    1996  79.9    True
# 31          4           robert aderholt                    1996  20.1   False
# 32          5                 mo brooks                    2010  61.1    True
# 33          5                 mo brooks                    2010  39.9   False
# 34          6               gary palmer                    2014  69.3    True
# 35          6               gary palmer                    2014  30.7   False
# 36          7              terri sewell                    2010   NaN    True
# 37          0                 don young                    1972  54.0    True
# 38          1             tom ohalleran                    2016  53.8    True
# 39          1             tom ohalleran                    2016  46.2   False
# 40          2            martha mcsally                    2014  54.4   False
# 41          2            martha mcsally                    2014  45.6   False
# 42          3             raul grijalva                    2002  63.4    True
# 43          3             raul grijalva                    2002  36.6   False
# 44          4                paul gosar                    2010  68.2    True
# 45          4                paul gosar                    2010  30.5   False
# 46          4                paul gosar                    2010   1.3   False
# 47          5                andy biggs                    2016  59.4    True
# 48          5                andy biggs                    2016  40.6   False
# 49          6          david schweikert                    2010  55.3    True
# 50          6          david schweikert                    2010  44.7   False
# 51          7             ruben gallego                    2014  85.7    True
# 52          7             ruben gallego                    2014  14.3   False
# 53          8              debbie lesko                    2018  55.6    True
# 54          8              debbie lesko                    2018  44.4   False
# 55          9            kyrsten sinema                    2012  60.9   False
# 56          9            kyrsten sinema                    2012  39.1   False
# 57          1             rick crawford                    2010  69.0    True
# 58          1             rick crawford                    2010  28.7   False
# 59          1             rick crawford                    2010   2.3   False
# 60          2               french hill                    2014  52.1    True
# 61          2               french hill                    2014  45.8   False
# 62          2               french hill                    2014   2.0   False
# 63          3              steve womack                    2010  64.9    True
# 64          3              steve womack                    2010  32.5   False
# 65          3              steve womack                    2010   2.6   False
# 66          3              steve womack                    2010   NaN   False
# 67          4           bruce westerman                    2014  66.8    True
# 68          4           bruce westerman                    2014  31.3   False
# 69          4           bruce westerman                    2014   1.9   False
# 70          4           bruce westerman                    2014   NaN   False
# 71          4           bruce westerman                    2014   NaN   False
# 72          1              doug lamalfa                    2012   NaN    True
# 73          1              doug lamalfa                    2012   NaN   False
# 74          2             jared huffman                    2012   NaN    True
# 75          2             jared huffman                    2012   NaN   False
# 76          3            john garamendi                    2009   NaN    True
# 77          3            john garamendi                    2009   NaN   False
# 78          4            tom mcclintock                    2008   NaN    True
# 79          4            tom mcclintock                    2008   NaN   False
# 80          5             mike thompson                    1998   NaN    True
# 81          6              doris matsui                    2005   NaN    True
# 82          6              doris matsui                    2005   NaN   False
# 83          7                  ami bera                    2012   NaN    True
# 84          7                  ami bera                    2012   NaN   False
# 85          8                 paul cook                    2012   NaN    True
# 86          8                 paul cook                    2012   NaN   False
# 87          9            jerry mcnerney                    2006   NaN    True
# 88          9            jerry mcnerney                    2006   NaN   False
# 89         10               jeff denham                    2010   NaN   False
