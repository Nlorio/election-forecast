# %% [markdown]
# # Importing Packages

# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading in the data

# %%
whoa = pd.read_csv("DailyMarketData_Fixed.csv", sep = "|")
whoa.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b3dbb8a21662> in <module>
# ----> 1 whoa = pd.read_csv("DailyMarketData_Fixed.csv", sep = "|")
#       2 whoa.head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
whoa[whoa["MarketName"]=="Will Nancy Pelosi be re-elected House Democratic leader?"]
# Out:
#        MarketId                                         MarketName  \
# 54002      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54003      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54004      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54005      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54006      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54007      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54008      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54009      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54010      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54011      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54012      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54013      2739  Will Nancy Pelosi be re-elected House Democrat...
# 54014      2739  Will Nancy Pelosi be re-elected House Democrat...
# ...

# %%
[(len(whoa[x == whoa["MarketName"]]),x) for x in whoa["MarketName"].unique()]
# Out:
# [(21237, 'Who will win the 2016 U.S. presidential election?'),
#  (2026, 'Which party will win the 2016 U.S. presidential election?'),
#  (879, 'Who will be elected Prime Minister of Canada in 2015?'),
#  (672, 'Will Republicans maintain a Senate majority after the next election?'),
#  (637,
#   'Will the Republican presidential nominee win at least 370 electoral votes in 2016?'),
#  (638,
#   'Will the Democratic presidential nominee win at least 370 electoral votes in 2016?'),
#  (266,
#   'Will Julie Christensen be elected supervisor of San Francisco District 3 in 2015?'),
#  (273, 'Will Ed Lee be reelected mayor of San Francisco in 2015?'),
#  (553, 'Will a woman be elected U.S. President in 2016?'),
#  (738, 'Which woman will be selected for the new $10 bill by year-end 2015?'),
#  (55,
#   'Will Enda Kenny be re-elected taoiseach after the Irish general election?'),
#  (72, 'Will the Select Committee on Benghazi publish a new report by May 2?'),
# ...

# %%
whoa["Date"].unique()
# Out:
# array(['2015-06-02', '2015-06-03', '2015-06-04', ..., '2018-06-12',
#        '2018-06-13', '2018-06-14'], dtype=object)
