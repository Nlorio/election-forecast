# %%
import pandas as pd
import numpy as np

from sklearn.base import BaseEstimator, TransformerMixin

# %%
house = pd.read_csv('../data/cleaned/RCP_house.csv', index_col=0)
house.head()
# Out:
#                           Race/Topic (Click to Sort)      Poll  \
# 0  Pennsylvania 12th District Special Election - ...   PPP (D)
# 1  New Hampshire 1st District - Guinta vs. Shea-P...   PPP (D)
# 2        New Hampshire 2nd District - Bass vs. Swett   PPP (D)
# 3  New Hampshire 1st District - Guinta vs. Shea-P...  WMUR/UNH
# 4        New Hampshire 2nd District - Bass vs. Swett  WMUR/UNH
#
#                      Results     Spread        Date    Year
# 0         Burns 44, Critz 41   Burns +3  2010-04-20  2010.0
# 1  Guinta 46, Shea-Porter 45  Guinta +1  2010-04-22  2010.0
# 2          Bass 47, Swett 32   Bass +15  2010-04-22  2010.0
# 3  Guinta 42, Shea-Porter 38  Guinta +4  2010-04-30  2010.0
# 4          Bass 44, Swett 27   Bass +17  2010-04-30  2010.0

# %%
senate = pd.read_csv('../data/cleaned/RCP_senate.csv', index_col=0)
senate.head()
# Out:
#                   Race/Topic (Click to Sort)                 Poll  \
# 0  Florida Senate - Rubio vs. Meek vs. Crist           Quinnipiac
# 1      Arkansas Senate - Boozman vs. Lincoln  R2000/Daily Kos (D)
# 2       Arkansas Senate - Boozman vs. Halter  R2000/Daily Kos (D)
# 3            Florida Senate - Rubio vs. Meek           Quinnipiac
# 4        Florida Senate - Republican Primary           Quinnipiac
#
#                        Results      Spread        Date    Year
# 0  Crist 32, Rubio 30, Meek 24    Crist +2  2010-04-15  2010.0
# 1       Boozman 50, Lincoln 43  Boozman +7  2010-04-15  2010.0
# 2        Boozman 48, Halter 41  Boozman +7  2010-04-15  2010.0
# 3            Rubio 42, Meek 38    Rubio +4  2010-04-15  2010.0
# 4           Rubio 56, Crist 33   Rubio +23  2010-04-15  2010.0

# %%
governor = pd.read_csv('../data/cleaned/RCP_governor.csv', index_col=0)
governor.head()
# Out:
#                      Race/Topic (Click to Sort)               Poll  \
# 0  Colorado Governor - McInnis vs. Hickenlooper  Rasmussen Reports
# 1         Arizona Governor - Republican Primary  Rasmussen Reports
# 2        New York Governor - Republican Primary              Siena
# 3            New York Governor - Levy vs. Cuomo              Siena
# 4           New York Governor - Lazio vs. Cuomo              Siena
#
#                                      Results      Spread        Date    Year
# 0                Hickenlooper 42, McInnis 48  McInnis +6  2010-04-16  2010.0
# 1  Brewer 26, Mills 18, Martin 12, Munger 14   Brewer +8  2010-04-17  2010.0
# 2             Lazio 29, Levy 15, Paladino 13   Lazio +14  2010-04-18  2010.0
# 3                          Cuomo 58, Levy 23   Cuomo +35  2010-04-18  2010.0
# 4                         Cuomo 61, Lazio 24   Cuomo +37  2010-04-18  2010.0

# %%
class ExtractInfo(BaseEstimator, TransformerMixin):
    """
        Extract information from RealClearPolitics polling data.
        Supported race types:
            - 'house'
            - 'senate'
            - 'governor'
        """
    def __init__(self, race_type):
        if race_type in ['house', 'senate', 'governor']:
            self.race_type = race_type
        else:
            raise NotImplementedError(f"Race type '{race_type}' is not supported")
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):     
        # Extract race name
        race_name = X['Race/Topic (Click to Sort)'] 
        race_name = race_name.str.split(' - ').map(lambda x: x[0].strip())
        
        # Extract state
        state = race_name.copy()
        if self.race_type == 'house':
            state = state.str.replace('At-Large', '0')
            state = state.str.extract(r"(.*) \d.*", expand=False)
        elif self.race_type == 'senate':
            state = state.str.extract(r"(.*) Senate", expand=False)
        elif self.race_type == 'governor':
            state = state.str.extract(r"(.*) Governor", expand=False)
        
        # Extract candidate names and values
        all_poll_results = X['Results'].str.split(',')
        candidates = []
        for row in all_poll_results:
            poll_results = {}
            for candidate in row:
                split = candidate.split()
                candidate_name = ' '.join([x.strip() for x in split[:-1]]) if len(split) > 1 else split[0]
                candidate_value = float(split[-1]) if len(split) > 1 else 0
                
                poll_results[candidate_name] = candidate_value
            
            candidates.append(poll_results)
            
        # Extract spread
        spread_split = X['Spread'].str.split()
        poll_leader = spread_split.map(lambda x: ' '.join(x[:-1]) if len(x) > 1 else np.nan)
        poll_spread = spread_split.map(lambda x: float(x[-1]) if len(x) > 1 else np.nan)
        
        return pd.DataFrame({'race_name': race_name,
                             'race_type': self.race_type,
                             'state': state,
                             'poll_results': candidates,
                             'poll_leader': poll_leader,
                             'poll_spread': poll_spread,
                             'date': X['Date']})

# %%
ei_house = ExtractInfo('house')
ei_senate = ExtractInfo('senate')
ei_governor = ExtractInfo('governor')

# %%
ei_house.transform(house)
# Out:
#                                        race_name race_type           state  \
# 0    Pennsylvania 12th District Special Election     house    Pennsylvania
# 1                     New Hampshire 1st District     house   New Hampshire
# 2                     New Hampshire 2nd District     house   New Hampshire
# 3                     New Hampshire 1st District     house   New Hampshire
# 4                     New Hampshire 2nd District     house   New Hampshire
# 5    Pennsylvania 12th District Special Election     house    Pennsylvania
# 6    Pennsylvania 12th District Special Election     house    Pennsylvania
# 7                          Maryland 1st District     house        Maryland
# 8           Hawaii 1st District Special Election     house          Hawaii
# 9    Pennsylvania 12th District Special Election     house    Pennsylvania
# 10   Pennsylvania 12th District Special Election     house    Pennsylvania
# 11   Pennsylvania 12th District Special Election     house    Pennsylvania
# 12                   South Carolina 4th District     house  South Carolina
# 13                   North Carolina 2nd District     house  North Carolina
# 14                        Minnesota 6th District     house       Minnesota
# 15                           Nevada 3rd District     house          Nevada
# 16                         Virginia 5th District     house        Virginia
# 17                         Virginia 9th District     house        Virginia
# 18                       New Mexico 1st District     house      New Mexico
# 19                         Kentucky 6th District     house        Kentucky
# 20                  North Carolina 11th District     house  North Carolina
# 21                           Nevada 3rd District     house          Nevada
# 22                         Virginia 5th District     house        Virginia
# 23                        New York 20th District     house        New York
# 24                        New York 23rd District     house        New York
# 25                        New York 25th District     house        New York
# 26                     Pennsylvania 3rd District     house    Pennsylvania
# 27                    Pennsylvania 10th District     house    Pennsylvania
# 28                    Pennsylvania 11th District     house    Pennsylvania
# 29                    Pennsylvania 12th District     house    Pennsylvania
# ..                                           ...       ...             ...
# 605                        Florida 26th District     house         Florida
# 606                       Virginia 10th District     house        Virginia
# 607                      New Jersey 3rd District     house      New Jersey
# 608                      New Jersey 2nd District     house      New Jersey
# 609                     California 10th District     house      California
# 610                     California 49th District     house      California
# 611                       Illinois 13th District     house        Illinois
# 612                            Ohio 1st District     house            Ohio
# 613                           Texas 7th District     house           Texas
# 614                      New Jersey 3rd District     house      New Jersey
# 615                            Utah 4th District     house            Utah
# 616                   Pennsylvania 10th District     house    Pennsylvania
# 617                        Illinois 6th District     house        Illinois
# 618                            Iowa 3rd District     house            Iowa
# 619                       New York 11th District     house        New York
# 620                       New York 24th District     house        New York
# 621                      New Mexico 1st District     house      New Mexico
# 622                     California 25th District     house      California
# 623                      New Mexico 2nd District     house      New Mexico
# 624                       New York 27th District     house        New York
# 625                        Virginia 7th District     house        Virginia
# 626                     California 50th District     house      California
# 627                          Kansas 2nd District     house          Kansas
# 628                          Kansas 3rd District     house          Kansas
# 629                    Montana At-Large District     house         Montana
# 630                  North Carolina 2nd District     house  North Carolina
# 631                    Pennsylvania 1st District     house    Pennsylvania
# 632                   Pennsylvania 10th District     house    Pennsylvania
# 633                       New York 19th District     house        New York
# 634                            Utah 4th District     house            Utah
#
#                                           poll_results      poll_leader  \
# 0                       {'Burns': 44.0, 'Critz': 41.0}            Burns
# 1                {'Guinta': 46.0, 'Shea-Porter': 45.0}           Guinta
# 2                        {'Bass': 47.0, 'Swett': 32.0}             Bass
# 3                {'Guinta': 42.0, 'Shea-Porter': 38.0}           Guinta
# 4                        {'Bass': 44.0, 'Swett': 27.0}             Bass
# 5                       {'Critz': 40.0, 'Burns': 46.0}            Burns
# 6                       {'Burns': 46.0, 'Critz': 40.0}            Burns
# 7                   {'Harris': 39.0, 'Kratovil': 36.0}           Harris
# 8       {'Djou': 36.0, 'Case': 28.0, 'Hanabusa': 22.0}             Djou
# 9                       {'Critz': 44.0, 'Burns': 38.0}            Critz
# 10                      {'Burns': 38.0, 'Critz': 44.0}            Critz
# 11                      {'Critz': 47.0, 'Burns': 48.0}            Burns
# 12   {'Gowdy': 37.0, 'Inglis': 33.0, 'Lee': 9.0, 'T...            Gowdy
# 13   {'Ellmers': 39.0, 'Etheridge': 38.0, 'Rose': 1...          Ellmers
# 14   {'Bachmann': 48.0, 'Clark': 39.0, 'Anderson': ...         Bachmann
# 15                       {'Titus': 42.0, 'Heck': 40.0}            Titus
# 16                   {'Hurt': 58.0, 'Perriello': 35.0}             Hurt
# 17                 {'Boucher': 52.0, 'Griffith': 39.0}          Boucher
# 18                  {'Barela': 51.0, 'Heinrich': 45.0}           Barela
# 19                    {'Chandler': 46.0, 'Barr': 32.0}         Chandler
# 20                    {'Shuler': 45.0, 'Miller': 44.0}           Shuler
# 21                       {'Titus': 43.0, 'Heck': 42.0}            Titus
# 22                   {'Hurt': 49.0, 'Perriello': 43.0}             Hurt
# 23                    {'Murphy': 45.0, 'Gibson': 40.0}           Murphy
# 24                     {'Owens': 41.0, 'Doheny': 39.0}            Owens
# 25                   {'Maffei': 44.0, 'Buerkle': 41.0}           Maffei
# 26                 {'Kelly': 52.0, 'Dahlkemper': 38.0}            Kelly
# 27                    {'Marino': 52.0, 'Carney': 37.0}           Marino
# 28               {'Barletta': 52.0, 'Kanjorski': 41.0}         Barletta
# 29                      {'Burns': 44.0, 'Critz': 40.0}            Burns
# ..                                                 ...              ...
# 605         {'Mucarsel-Powell': 45.0, 'Curbelo': 44.0}  Mucarsel-Powell
# 606                 {'Wexton': 56.0, 'Comstock': 43.0}           Wexton
# 607                   {'MacArthur': 46.0, 'Kim': 48.0}              Kim
# 608               {'Van Drew': 55.0, 'Grossman': 38.0}         Van Drew
# 609                   {'Harder': 47.0, 'Denham': 45.0}           Harder
# 610                    {'Levin': 53.0, 'Harkey': 39.0}            Levin
# 611                 {'Davis': 46.0, 'Londrigan': 41.0}            Davis
# 612                  {'Chabot': 50.0, 'Pureval': 41.0}           Chabot
# 613              {'Culberson': 46.0, 'Fletcher': 45.0}        Culberson
# 614                   {'MacArthur': 45.0, 'Kim': 44.0}        MacArthur
# 615                    {'McAdams': 45.0, 'Love': 45.0}              NaN
# 616                     {'Perry': 45.0, 'Scott': 43.0}            Perry
# 617                   {'Casten': 46.0, 'Roskam': 44.0}           Casten
# 618                      {'Axne': 43.0, 'Young': 41.0}             Axne
# 619                    {'Donovan': 44.0, 'Rose': 40.0}          Donovan
# 620                    {'Katko': 53.0, 'Balter': 39.0}            Katko
# 621            {'Haaland': 51.0, 'Arnold-Jones': 41.0}          Haaland
# 622                     {'Knight': 48.0, 'Hill': 44.0}           Knight
# 623                   {'Herrell': 47.0, 'Small': 47.0}              NaN
# 624                {'Collins': 44.0, 'McMurray': 40.0}          Collins
# 625                 {'Spanberger': 46.0, 'Brat': 45.0}       Spanberger
# 626             {'Hunter': 48.0, 'Campa-Najjar': 45.0}           Hunter
# 627                   {'Watkins': 48.0, 'Davis': 41.0}          Watkins
# 628                    {'Davids': 55.0, 'Yoder': 43.0}           Davids
# 629              {'Gianforte': 48.0, 'Williams': 48.0}              NaN
# 630                 {'Holding': 49.0, 'Coleman': 40.0}          Holding
# 631             {'Fitzpatrick': 47.0, 'Wallace': 46.0}      Fitzpatrick
# 632                     {'Perry': 49.0, 'Scott': 46.0}            Perry
# 633                    {'Faso': 44.0, 'Delgado': 49.0}          Delgado
# 634                    {'McAdams': 50.0, 'Love': 43.0}          McAdams
#
#      poll_spread        date
# 0            3.0  2010-04-20
# 1            1.0  2010-04-22
# 2           15.0  2010-04-22
# 3            4.0  2010-04-30
# 4           17.0  2010-04-30
# 5            6.0  2010-05-01
# 6            6.0  2010-05-01
# 7            3.0  2010-05-01
# 8            8.0  2010-05-02
# 9            6.0  2010-05-12
# 10           6.0  2010-05-12
# 11           1.0  2010-05-17
# 12           4.0  2010-06-06
# 13           1.0  2010-06-17
# 14           9.0  2010-07-13
# 15           2.0  2010-07-18
# 16          23.0  2010-07-21
# 17          13.0  2010-07-22
# 18           6.0  2010-07-27
# 19          14.0  2010-07-29
# 20           1.0  2010-08-02
# 21           1.0  2010-08-15
# 22           6.0  2010-08-16
# 23           5.0  2010-08-16
# 24           2.0  2010-08-16
# 25           3.0  2010-08-16
# 26          14.0  2010-08-16
# 27          15.0  2010-08-16
# 28          11.0  2010-08-16
# 29           4.0  2010-08-16
# ..           ...         ...
# 605          1.0  2018-10-25
# 606         13.0  2018-10-25
# 607          2.0  2018-10-25
# 608         17.0  2018-10-25
# 609          2.0  2018-10-26
# 610         14.0  2018-10-26
# 611          5.0  2018-10-26
# 612          9.0  2018-10-26
# 613          1.0  2018-10-26
# 614          1.0  2018-10-26
# 615          NaN  2018-10-27
# 616          2.0  2018-10-27
# 617          2.0  2018-10-27
# 618          2.0  2018-10-28
# 619          4.0  2018-10-28
# 620         14.0  2018-10-28
# 621         10.0  2018-10-29
# 622          4.0  2018-10-29
# 623          NaN  2018-10-29
# 624          4.0  2018-10-29
# 625          1.0  2018-10-29
# 626          3.0  2018-10-30
# 627          7.0  2018-10-30
# 628         12.0  2018-10-30
# 629          NaN  2018-10-30
# 630          9.0  2018-10-30
# 631          1.0  2018-10-30
# 632          3.0  2018-10-30
# 633          5.0  2018-10-30
# 634          7.0  2018-10-30
#
# [635 rows x 7 columns]

# %%
ei_senate.transform(senate)
# Out:
#                                 race_name race_type           state  \
# 0                          Florida Senate    senate         Florida
# 1                         Arkansas Senate    senate        Arkansas
# 2                         Arkansas Senate    senate        Arkansas
# 3                          Florida Senate    senate         Florida
# 4                          Florida Senate    senate         Florida
# 5                         Arkansas Senate    senate        Arkansas
# 6                          Florida Senate    senate         Florida
# 7                          Arizona Senate    senate         Arizona
# 8                           Nevada Senate    senate          Nevada
# 9                         New York Senate    senate        New York
# 10                         Indiana Senate    senate         Indiana
# 11                         Indiana Senate    senate         Indiana
# 12                   New Hampshire Senate    senate   New Hampshire
# 13                  North Carolina Senate    senate  North Carolina
# 14                  North Carolina Senate    senate  North Carolina
# 15                   New Hampshire Senate    senate   New Hampshire
# 16                         Florida Senate    senate         Florida
# 17                       Wisconsin Senate    senate       Wisconsin
# 18                       Wisconsin Senate    senate       Wisconsin
# 19                      California Senate    senate      California
# 20                      California Senate    senate      California
# 21                         Georgia Senate    senate         Georgia
# 22                      Washington Senate    senate      Washington
# 23                      Washington Senate    senate      Washington
# 24                      Washington Senate    senate      Washington
# 25                      Washington Senate    senate      Washington
# 26                    North Dakota Senate    senate    North Dakota
# 27                  North Carolina Senate    senate  North Carolina
# 28                  North Carolina Senate    senate  North Carolina
# 29                         Arizona Senate    senate         Arizona
# ...                                   ...       ...             ...
# 3338  Mississippi Senate Special Election    senate     Mississippi
# 3339  Mississippi Senate Run-Off Election    senate     Mississippi
# 3340                       Florida Senate    senate         Florida
# 3341                      Michigan Senate    senate        Michigan
# 3342                    New Jersey Senate    senate      New Jersey
# 3343                      Michigan Senate    senate        Michigan
# 3344                    California Senate    senate      California
# 3345                       Florida Senate    senate         Florida
# 3346                         Texas Senate    senate           Texas
# 3347                      Missouri Senate    senate        Missouri
# 3348                      Michigan Senate    senate        Michigan
# 3349                       Indiana Senate    senate         Indiana
# 3350                       Arizona Senate    senate         Arizona
# 3351                       Florida Senate    senate         Florida
# 3352                       Florida Senate    senate         Florida
# 3353                         Texas Senate    senate           Texas
# 3354                      Michigan Senate    senate        Michigan
# 3355                      Michigan Senate    senate        Michigan
# 3356                    New Mexico Senate    senate      New Mexico
# 3357                 Massachusetts Senate    senate   Massachusetts
# 3358                  Rhode Island Senate    senate    Rhode Island
# 3359                    New Jersey Senate    senate      New Jersey
# 3360                         Texas Senate    senate           Texas
# 3361                   Connecticut Senate    senate     Connecticut
# 3362                       Florida Senate    senate         Florida
# 3363                       Florida Senate    senate         Florida
# 3364                       Arizona Senate    senate         Arizona
# 3365                       Montana Senate    senate         Montana
# 3366                  North Dakota Senate    senate    North Dakota
# 3367                          Ohio Senate    senate            Ohio
#
#                                            poll_results poll_leader  \
# 0          {'Crist': 32.0, 'Rubio': 30.0, 'Meek': 24.0}       Crist
# 1                    {'Boozman': 50.0, 'Lincoln': 43.0}     Boozman
# 2                     {'Boozman': 48.0, 'Halter': 41.0}     Boozman
# 3                         {'Rubio': 42.0, 'Meek': 38.0}       Rubio
# 4                        {'Rubio': 56.0, 'Crist': 33.0}       Rubio
# 5                     {'Lincoln': 45.0, 'Halter': 33.0}     Lincoln
# 6                         {'Crist': 48.0, 'Meek': 34.0}       Crist
# 7                    {'McCain': 47.0, 'Hayworth': 42.0}      McCain
# 8                        {'Lowden': 47.0, 'Reid': 37.0}      Lowden
# 9               {'Gillibrand': 46.0, 'DioGuardi': 27.0}  Gillibrand
# 10                   {'Coats': 54.0, 'Ellsworth': 33.0}       Coats
# 11              {'Hostettler': 50.0, 'Ellsworth': 33.0}  Hostettler
# 12                      {'Ayotte': 47.0, 'Hodes': 40.0}      Ayotte
# 13                     {'Burr': 50.0, 'Marshall': 32.0}        Burr
# 14                   {'Burr': 53.0, 'Cunningham': 31.0}        Burr
# 15    {'Ayotte': 43.0, 'Binnie': 19.0, 'Bender': 11....      Ayotte
# 16         {'Crist': 30.0, 'Rubio': 37.0, 'Meek': 22.0}       Rubio
# 17                     {'Feingold': 49.0, 'Wall': 43.0}    Feingold
# 18                 {'Feingold': 49.0, 'Westlake': 38.0}    Feingold
# 19    {'Campbell': 34.0, 'Fiorina': 27.0, 'DeVore': ...    Campbell
# 20    {'Campbell': 31.0, 'Fiorina': 17.0, 'DeVore': ...    Campbell
# 21                  {'Isakson': 51.0, 'Thurmond': 35.0}     Isakson
# 22                    {'Murray': 45.0, 'Widener': 43.0}      Murray
# 23                     {'Murray': 46.0, 'Didier': 44.0}      Murray
# 24                     {'Murray': 46.0, 'Benton': 44.0}      Murray
# 25                      {'Murray': 42.0, 'Rossi': 52.0}       Rossi
# 26                     {'Hoeven': 69.0, 'Potter': 24.0}      Hoeven
# 27    {'Marshall': 23.0, 'Cunningham': 19.0, 'Lewis'...    Marshall
# 28    {'Marshall': 26.0, 'Cunningham': 23.0, 'Lewis'...    Marshall
# 29                 {'Hayworth': 37.0, 'Glassman': 30.0}    Hayworth
# ...                                                 ...         ...
# 3338  {'Hyde-Smith': 38.0, 'Espy': 29.0, 'McDaniel':...  Hyde-Smith
# 3339                 {'Hyde-Smith': 50.0, 'Espy': 36.0}  Hyde-Smith
# 3340                    {'Nelson': 49.0, 'Scott': 45.0}      Nelson
# 3341                  {'Stabenow': 53.0, 'James': 37.0}    Stabenow
# 3342                  {'Menendez': 51.0, 'Hugin': 46.0}    Menendez
# 3343                  {'Stabenow': 49.0, 'James': 42.0}    Stabenow
# 3344                  {'Feinstein': 43.0, 'Leon': 27.0}   Feinstein
# 3345                    {'Nelson': 46.0, 'Scott': 45.0}      Nelson
# 3346                   {'Cruz': 51.0, 'O'Rourke': 45.0}        Cruz
# 3347                {'Hawley': 49.0, 'McCaskill': 45.0}      Hawley
# 3348                  {'Stabenow': 52.0, 'James': 46.0}    Stabenow
# 3349  {'Braun': 46.0, 'Donnelly': 43.0, 'Brenton': 3.0}       Braun
# 3350                  {'Sinema': 47.0, 'McSally': 44.0}      Sinema
# 3351                    {'Nelson': 46.0, 'Scott': 46.0}         NaN
# 3352                    {'Nelson': 48.0, 'Scott': 44.0}      Nelson
# 3353                   {'Cruz': 51.0, 'O'Rourke': 46.0}        Cruz
# 3354                  {'Stabenow': 52.0, 'James': 43.0}    Stabenow
# 3355                  {'Stabenow': 53.0, 'James': 36.0}    Stabenow
# 3356  {'Heinrich': 48.0, 'Rich': 32.0, 'Johnson': 16.0}    Heinrich
# 3357                    {'Warren': 56.0, 'Diehl': 34.0}      Warren
# 3358             {'Whitehouse': 55.0, 'Flanders': 36.0}  Whitehouse
# 3359                  {'Menendez': 47.0, 'Hugin': 42.0}    Menendez
# 3360                   {'Cruz': 52.0, 'O'Rourke': 42.0}        Cruz
# 3361                    {'Murphy': 56.0, 'Corey': 41.0}      Murphy
# 3362                    {'Nelson': 47.0, 'Scott': 46.0}      Nelson
# 3363                    {'Nelson': 45.0, 'Scott': 43.0}      Nelson
# 3364                  {'Sinema': 50.0, 'McSally': 44.0}      Sinema
# 3365                {'Tester': 48.0, 'Rosendale': 45.0}      Tester
# 3366                 {'Cramer': 54.0, 'Heitkamp': 45.0}      Cramer
# 3367                   {'Brown': 49.0, 'Renacci': 43.0}       Brown
#
#       poll_spread
# 0             2.0
# 1             7.0
# 2             7.0
# 3             4.0
# 4            23.0
# 5            12.0
# 6            14.0
# 7             5.0
# 8            10.0
# 9            19.0
# 10           21.0
# 11           17.0
# 12            7.0
# 13           18.0
# 14           22.0
# 15           24.0
# 16            7.0
# 17            6.0
# 18           11.0
# 19            7.0
# 20           14.0
# 21           16.0
# 22            2.0
# 23            2.0
# 24            2.0
# 25           10.0
# 26           45.0
# 27            4.0
# 28            3.0
# 29            7.0
# ...           ...
# 3338          9.0
# 3339         14.0
# 3340          4.0
# 3341         16.0
# 3342          5.0
# 3343          7.0
# 3344         16.0
# 3345          1.0
# 3346          6.0
# 3347          4.0
# 3348          6.0
# 3349          3.0
# 3350          3.0
# 3351          NaN
# 3352          4.0
# 3353          5.0
# 3354          9.0
# 3355         17.0
# 3356         16.0
# 3357         22.0
# 3358         19.0
# 3359          5.0
# 3360         10.0
# 3361         15.0
# 3362          1.0
# 3363          2.0
# 3364          6.0
# 3365          3.0
# 3366          9.0
# 3367          6.0
#
# [3368 rows x 6 columns]
