# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from pathlib import Path
DATA_DIR = Path('..')/'..'/'data'

# %% [markdown]
# # Loading data

# %%
house_polls = pd.read_pickle(DATA_DIR/'cleaned'/'HousePollwithWinner_Final.pkl')

# %%
house_polls.head()
# Out:
#                                      race_name race_type state  \
# 0  pennsylvania 12th district special election     house    PA
# 1                   new hampshire 1st district     house    NH
# 2                   new hampshire 2nd district     house    NH
# 3                   new hampshire 1st district     house    NH
# 4                   new hampshire 2nd district     house    NH
#
#           top_candidates  pollster                           poll_results  \
# 0         [burns, critz]   ppp (d)         {'burns': 44.0, 'critz': 41.0}
# 1  [guinta, shea-porter]   ppp (d)  {'guinta': 46.0, 'shea-porter': 45.0}
# 2          [bass, swett]   ppp (d)          {'bass': 47.0, 'swett': 32.0}
# 3  [guinta, shea-porter]  wmur/unh  {'guinta': 42.0, 'shea-porter': 38.0}
# 4          [bass, swett]  wmur/unh          {'bass': 44.0, 'swett': 27.0}
#
#   poll_leader  poll_spread       date  winner winning_party  \
# 0       burns          3.0 2010-04-20   critz             d
# 1      guinta          1.0 2010-04-22  guinta             r
# 2        bass         15.0 2010-04-22    bass             r
# 3      guinta          4.0 2010-04-30  guinta             r
# 4        bass         17.0 2010-04-30    bass             r
#
#          election_date  district
# 0  2010-11-02 00:00:00        12
# 1  2010-11-02 00:00:00         1
# 2  2010-11-02 00:00:00         2
# 3  2010-11-02 00:00:00         1
# 4  2010-11-02 00:00:00         2

# %%
house_polls.iloc[400:500, :]
# Out:
#                                  race_name race_type state  \
# 400                     maine 2nd district     house    ME
# 401                     maine 1st district     house    ME
# 402                     maine 2nd district     house    ME
# 403                      iowa 1st district     house    IA
# 404                      iowa 3rd district     house    IA
# 405                  new york 1st district     house    NY
# 406                  new york 3rd district     house    NY
# 407                  florida 13th district     house    FL
# 408                 minnesota 2nd district     house    MN
# 409                 minnesota 3rd district     house    MN
# 410             new hampshire 2nd district     house    NH
# 411             new hampshire 1st district     house    NH
# 412                 minnesota 8th district     house    MN
# 413             new hampshire 1st district     house    NH
# 414             new hampshire 2nd district     house    NH
# 415              montana at-large district     house    MT
# 416                     maine 1st district     house    ME
# 417                     maine 2nd district     house    ME
# 418                 new york 19th district     house    NY
# 419             new hampshire 2nd district     house    NH
# 420             new hampshire 1st district     house    NH
# 421                   indiana 9th district     house    IN
# 422                      iowa 1st district     house    IA
# 423                      iowa 3rd district     house    IA
# 424  georgia 6th district special election     house    GA
# 425  georgia 6th district run-off election     house    GA
# 426  georgia 6th district special election     house    GA
# 427  georgia 6th district special election     house    GA
# 428  georgia 6th district special election     house    GA
# 429  georgia 6th district special election     house    GA
# ..                                     ...       ...   ...
# 470    ohio 12th district special election     house    OH
# 471    ohio 12th district special election     house    OH
# 472                new jersey 3rd district     house    NJ
# 473                 new york 24th district     house    NY
# 474               california 50th district     house    CA
# 475                 new york 22nd district     house    NY
# 476                 new york 19th district     house    NY
# 477                 illinois 12th district     house    IL
# 478                  illinois 6th district     house    IL
# 479               california 48th district     house    CA
# 480                      utah 4th district     house    UT
# 481                  kentucky 6th district     house    KY
# 482                 minnesota 8th district     house    MN
# 483                 minnesota 3rd district     house    MN
# 484                      iowa 1st district     house    IA
# 485                      iowa 2nd district     house    IA
# 486                      iowa 3rd district     house    IA
# 487                      iowa 3rd district     house    IA
# 488             west virginia 3rd district     house    WV
# 489             west virginia 3rd district     house    WV
# 490                    texas 23rd district     house    TX
# 491                 new york 19th district     house    NY
# 492            north carolina 2nd district     house    NC
# 493                  virginia 7th district     house    VA
# 494              pennsylvania 7th district     house    PA
# 495                 wisconsin 1st district     house    WI
# 496                  colorado 6th district     house    CO
# 497                     maine 2nd district     house    ME
# 498                new mexico 1st district     house    NM
# 499      kansas 2nd congressional district     house    KS
#
#               top_candidates                     pollster  \
# 400         [poliquin, cain]      colby college/surveyusa
# 401      [pingree, holbrook]             press herald/unh
# 402         [poliquin, cain]             press herald/unh
# 403           [blum, vernon]                        loras
# 404          [young, mowrer]                        loras
# 405   [zeldin, throne-holst]                newsday/siena
# 406        [suozzi, martins]                newsday/siena
# 407           [crist, jolly]       univ. of north florida
# 408           [craig, lewis]               kstp/surveyusa
# 409        [paulsen, bonoff]               kstp/surveyusa
# 410       [kuster, lawrence]                    wmur/unh*
# 411    [shea-porter, guinta]                    wmur/unh*
# 412           [mills, nolan]               kstp/surveyusa
# 413    [shea-porter, guinta]           umass amherst/wbz*
# 414       [kuster, lawrence]           umass amherst/wbz*
# 415          [zinke, juneau]             montana state u.
# 416      [pingree, holbrook]             press herald/unh
# 417         [cain, poliquin]             press herald/unh
# 418         [teachout, faso]            wnyt-tv/surveyusa
# 419       [kuster, lawrence]                     wmur/unh
# 420    [shea-porter, guinta]                    wmur/unh*
# 421   [hollingsworth, yoder]          wthr/howey politics
# 422           [blum, vernon]                        loras
# 423          [young, mowrer]                        loras
# 424         [ossoff, handel]            wxia-tv/surveyusa
# 425         [ossoff, handel]  fox 5 atlanta/opinion savvy
# 426         [ossoff, handel]  fox 5 atlanta/opinion savvy
# 427         [ossoff, handel]              wsb-tv/landmark
# 428           [ossoff, gray]           clout research (r)
# 429         [ossoff, handel]                      emerson
# ..                       ...                          ...
# 470    [balderson, o'connor]                    monmouth*
# 471    [o'connor, balderson]                      emerson
# 472         [kim, macarthur]                     monmouth
# 473          [katko, balter]                        siena
# 474   [hunter, campa-najjar]            kgtv-tv/surveyusa
# 475       [brindisi, tenney]                        siena
# 476          [faso, delgado]                        siena
# 477            [bost, kelly]               ny times/siena
# 478         [roskam, casten]               ny times/siena
# 479     [rouda, rohrabacher]               ny times/siena
# 480          [love, mcadams]         utahpolicy/dan jones
# 481          [barr, mcgrath]               ny times/siena
# 482    [radinovich, stauber]               ny times/siena
# 483      [phillips, paulsen]               ny times/siena
# 484       [finkenauer, blum]                      emerson
# 485       [loebsack, peters]                      emerson
# 486            [young, axne]                      emerson
# 487            [young, axne]                      emerson
# 488          [miller, ojeda]               ny times/siena
# 489          [miller, ojeda]               ny times/siena
# 490      [hurd, ortiz jones]               ny times/siena
# 491          [delgado, faso]                     monmouth
# 492       [coleman, holding]       civitas (r)/surveyusa*
# 493       [brat, spanberger]               ny times/siena
# 494        [wild, nothstein]                    monmouth*
# 495           [steil, bryce]               ny times/siena
# 496          [crow, coffman]               ny times/siena
# 497       [poliquin, golden]               ny times/siena
# 498  [haaland, arnold-jones]         albuquerque journal*
# 499         [davis, watkins]               ny times/siena
#
#                                           poll_results    poll_leader  \
# 400                   {'poliquin': 50.0, 'cain': 45.0}       poliquin
# 401                {'pingree': 64.0, 'holbrook': 22.0}        pingree
# 402                   {'poliquin': 45.0, 'cain': 35.0}       poliquin
# 403                     {'blum': 45.0, 'vernon': 38.0}           blum
# 404                    {'young': 46.0, 'mowrer': 36.0}          young
# 405             {'zeldin': 53.0, 'throne-holst': 38.0}         zeldin
# 406                  {'suozzi': 50.0, 'martins': 34.0}         suozzi
# 407                     {'crist': 54.0, 'jolly': 36.0}          crist
# 408                     {'craig': 46.0, 'lewis': 41.0}          craig
# 409                  {'paulsen': 49.0, 'bonoff': 38.0}        paulsen
# 410                 {'kuster': 54.0, 'lawrence': 24.0}         kuster
# 411              {'shea-porter': 44.0, 'guinta': 32.0}    shea-porter
# 412                     {'mills': 45.0, 'nolan': 41.0}          mills
# 413              {'shea-porter': 41.0, 'guinta': 37.0}    shea-porter
# 414                 {'kuster': 53.0, 'lawrence': 42.0}         kuster
# 415                    {'zinke': 50.0, 'juneau': 31.0}          zinke
# 416                {'pingree': 61.0, 'holbrook': 28.0}        pingree
# 417                   {'poliquin': 44.0, 'cain': 46.0}           cain
# 418                   {'teachout': 45.0, 'faso': 42.0}       teachout
# 419                 {'kuster': 48.0, 'lawrence': 34.0}         kuster
# 420              {'shea-porter': 37.0, 'guinta': 32.0}    shea-porter
# 421             {'hollingsworth': 44.0, 'yoder': 42.0}  hollingsworth
# 422                     {'blum': 47.0, 'vernon': 41.0}           blum
# 423                    {'young': 44.0, 'mowrer': 39.0}          young
# 424  {'ossoff': 43.0, 'handel': 15.0, 'gray': 14.0,...         ossoff
# 425                   {'ossoff': 44.0, 'handel': 42.0}         ossoff
# 426  {'ossoff': 42.0, 'handel': 21.0, 'gray': 11.0,...         ossoff
# 427  {'ossoff': 45.0, 'handel': 17.0, 'gray': 9.0, ...         ossoff
# 428  {'ossoff': 41.0, 'handel': 15.0, 'gray': 17.0,...         ossoff
# 429  {'ossoff': 43.0, 'handel': 17.0, 'gray': 15.0,...         ossoff
# ..                                                 ...            ...
# 470              {'balderson': 46.0, 'o'connor': 45.0}      balderson
# 471              {'balderson': 46.0, 'o'connor': 47.0}       o'connor
# 472                   {'kim': 45.0, 'macarthur': 44.0}            kim
# 473                    {'katko': 54.0, 'balter': 39.0}          katko
# 474             {'hunter': 47.0, 'campa-najjar': 39.0}         hunter
# 475                 {'brindisi': 46.0, 'tenney': 44.0}       brindisi
# 476                    {'delgado': 40.0, 'faso': 45.0}           faso
# 477                      {'bost': 44.0, 'kelly': 43.0}           bost
# 478                   {'roskam': 45.0, 'casten': 44.0}         roskam
# 479               {'rouda': 45.0, 'rohrabacher': 45.0}            NaN
# 480                    {'love': 49.0, 'mcadams': 46.0}           love
# 481                    {'barr': 47.0, 'mcgrath': 46.0}           barr
# 482              {'radinovich': 44.0, 'stauber': 43.0}     radinovich
# 483                {'phillips': 51.0, 'paulsen': 42.0}       phillips
# 484                 {'finkenauer': 43.0, 'blum': 38.0}     finkenauer
# 485                 {'loebsack': 45.0, 'peters': 21.0}       loebsack
# 486                      {'axne': 31.0, 'young': 47.0}          young
# 487                      {'young': 47.0, 'axne': 31.0}          young
# 488                    {'ojeda': 40.0, 'miller': 48.0}         miller
# 489                    {'miller': 48.0, 'ojeda': 40.0}         miller
# 490                {'hurd': 51.0, 'ortiz jones': 43.0}           hurd
# 491                    {'delgado': 48.0, 'faso': 45.0}        delgado
# 492                 {'coleman': 44.0, 'holding': 43.0}        coleman
# 493                 {'brat': 47.0, 'spanberger': 43.0}           brat
# 494                  {'wild': 47.0, 'nothstein': 45.0}           wild
# 495                     {'steil': 50.0, 'bryce': 44.0}          steil
# 496                    {'crow': 51.0, 'coffman': 40.0}           crow
# 497                 {'poliquin': 47.0, 'golden': 42.0}       poliquin
# 498            {'haaland': 49.0, 'arnold-jones': 41.0}        haaland
# 499                   {'davis': 45.0, 'watkins': 44.0}          davis
#
#      poll_spread       date         winner winning_party        election_date  \
# 400          5.0 2016-09-14       poliquin             r  2016-11-08 00:00:00
# 401         42.0 2016-09-25        pingree             d  2016-11-08 00:00:00
# 402         10.0 2016-09-25       poliquin             r  2016-11-08 00:00:00
# 403          7.0 2016-09-27           blum             r  2016-11-08 00:00:00
# 404         10.0 2016-09-27          young             r  2016-11-08 00:00:00
# 405         15.0 2016-10-08         zeldin             r  2016-11-08 00:00:00
# 406         16.0 2016-10-08         suozzi             d  2016-11-08 00:00:00
# 407         18.0 2016-10-13          crist             d  2016-11-08 00:00:00
# 408          5.0 2016-10-17          lewis             r  2016-11-08 00:00:00
# 409         11.0 2016-10-17        paulsen             r  2016-11-08 00:00:00
# 410         30.0 2016-10-21         kuster             d  2016-11-08 00:00:00
# 411         12.0 2016-10-21         guinta             r  2014-11-04 00:00:00
# 412          4.0 2016-10-24          nolan             d  2016-11-08 00:00:00
# 413          4.0 2016-10-25         guinta             r  2014-11-04 00:00:00
# 414         11.0 2016-10-25         kuster             d  2016-11-08 00:00:00
# 415         19.0 2016-10-26          zinke             r  2016-11-08 00:00:00
# 416         33.0 2016-10-30        pingree             d  2016-11-08 00:00:00
# 417          2.0 2016-10-30       poliquin             r  2016-11-08 00:00:00
# 418          3.0 2016-10-31           faso             r  2016-11-08 00:00:00
# 419         14.0 2016-10-31         kuster             d  2016-11-08 00:00:00
# 420          5.0 2016-10-31         guinta             r  2014-11-04 00:00:00
# 421          2.0 2016-11-04  hollingsworth             r  2016-11-08 00:00:00
# 422          6.0 2016-11-05           blum             r  2016-11-08 00:00:00
# 423          5.0 2016-11-05          young             r  2016-11-08 00:00:00
# 424         28.0 2017-04-04         handel             r  2017-06-20 00:00:00
# 425          2.0 2017-04-14         handel             r  2017-06-20 00:00:00
# 426         21.0 2017-04-14         handel             r  2017-06-20 00:00:00
# 427         28.0 2017-04-15         handel             r  2017-06-20 00:00:00
# 428         24.0 2017-04-17         handel             r  2017-06-20 00:00:00
# 429         26.0 2017-04-17         handel             r  2017-06-20 00:00:00
# ..           ...        ...            ...           ...                  ...
# 470          1.0 2018-08-01      balderson             r  2018-08-07 00:00:00
# 471          1.0 2018-08-06      balderson             r  2018-08-07 00:00:00
# 472          1.0 2018-08-14        <BLANK>       <BLANK>              <BLANK>
# 473         15.0 2018-08-27        <BLANK>       <BLANK>              <BLANK>
# 474          8.0 2018-08-27        <BLANK>       <BLANK>              <BLANK>
# 475          2.0 2018-08-29        <BLANK>       <BLANK>              <BLANK>
# 476          5.0 2018-08-30        <BLANK>       <BLANK>              <BLANK>
# 477          1.0 2018-09-07        <BLANK>       <BLANK>              <BLANK>
# 478          1.0 2018-09-07        <BLANK>       <BLANK>              <BLANK>
# 479          NaN 2018-09-07        <BLANK>       <BLANK>              <BLANK>
# 480          3.0 2018-09-07        <BLANK>       <BLANK>              <BLANK>
# 481          1.0 2018-09-08        <BLANK>       <BLANK>              <BLANK>
# 482          1.0 2018-09-09        <BLANK>       <BLANK>              <BLANK>
# 483          9.0 2018-09-10        <BLANK>       <BLANK>              <BLANK>
# 484          5.0 2018-09-10        <BLANK>       <BLANK>              <BLANK>
# 485         24.0 2018-09-10        <BLANK>       <BLANK>              <BLANK>
# 486         16.0 2018-09-10        <BLANK>       <BLANK>              <BLANK>
# 487         16.0 2018-09-10        <BLANK>       <BLANK>              <BLANK>
# 488          8.0 2018-09-11        <BLANK>       <BLANK>              <BLANK>
# 489          8.0 2018-09-11        <BLANK>       <BLANK>              <BLANK>
# 490          8.0 2018-09-12        <BLANK>       <BLANK>              <BLANK>
# 491          3.0 2018-09-12        <BLANK>       <BLANK>              <BLANK>
# 492          1.0 2018-09-13        <BLANK>       <BLANK>              <BLANK>
# 493          4.0 2018-09-13        <BLANK>       <BLANK>              <BLANK>
# 494          2.0 2018-09-13        <BLANK>       <BLANK>              <BLANK>
# 495          6.0 2018-09-14        <BLANK>       <BLANK>              <BLANK>
# 496         11.0 2018-09-15        <BLANK>       <BLANK>              <BLANK>
# 497          5.0 2018-09-15        <BLANK>       <BLANK>              <BLANK>
# 498          8.0 2018-09-16        <BLANK>       <BLANK>              <BLANK>
# 499          1.0 2018-09-16        <BLANK>       <BLANK>              <BLANK>
#
#      district
# 400         2
# 401         1
# 402         2
# 403         1
# 404         3
# 405         1
# 406         3
# 407        13
# 408         2
# 409         3
# 410         2
# 411         1
# 412         8
# 413         1
# 414         2
# 415         0
# 416         1
# 417         2
# 418        19
# 419         2
# 420         1
# 421         9
# 422         1
# 423         3
# 424         6
# 425         6
# 426         6
# 427         6
# 428         6
# 429         6
# ..        ...
# 470        12
# 471        12
# 472         3
# 473        24
# 474        50
# 475        22
# 476        19
# 477        12
# 478         6
# 479        48
# 480         4
# 481         6
# 482         8
# 483         3
# 484         1
# 485         2
# 486         3
# 487         3
# 488         3
# 489         3
# 490        23
# 491        19
# 492         2
# 493         7
# 494         7
# 495         1
# 496         6
# 497         2
# 498         1
# 499         2
#
# [100 rows x 13 columns]

# %%
house_polls = house_polls.replace("<BLANK>", np.nan)

# %% [markdown]
# # Feature extraction
#
# Initial exploration will only occur on house data, then replicated on other datasets (senate, governor).

# %% [markdown]
# ## What percent of poll leaders become winners?
#
# Starting from very simple features.

# %%
def find_winning_pct(party=None):
    """Find winning percentage for a party, or if not specified, overall."""
    if not party:
        winning_pct = (house_polls['poll_leader'] == house_polls['winner']).mean()
    else:
        subset = house_polls[house_polls['winning_party'] == party]
        winning_pct = (subset['poll_leader'] == subset['winner']).mean()
    return round(winning_pct * 100, 2)

# %%
print(f"{find_winning_pct()}% of poll leaders become winners")
# Out:
# 45.64% of poll leaders become winners

# %% [markdown]
# Does winning party play a role in this?

# %%
print(f"{find_winning_pct('r')}% of winning republicans had led the polls")
# Out:
# 68.54% of winning republicans had led the polls

# %%
print(f"{find_winning_pct('d')}% of winning democrats had led the polls")
# Out:
# 68.85% of winning democrats had led the polls

# %% [markdown]
# ## Poll Spread

# %%
result_win = house_polls[house_polls['poll_leader'] == house_polls['winner']]
result_lose = house_polls[house_polls['poll_leader'] != house_polls['winner']]

# %%
pd.DataFrame({
    'result_win': result_win['poll_spread'].describe(),
    'result_lose': result_lose['poll_spread'].describe()
})
# Out:
#        result_win  result_lose
# count  309.000000   340.000000
# mean     9.025890     6.494118
# std      6.747725     5.237990
# min      1.000000     1.000000
# 25%      4.000000     3.000000
# 50%      7.000000     5.000000
# 75%     13.000000     9.000000
# max     42.000000    28.000000

# %%
plt.figure(figsize=(12, 9))
plt.hist(result_win['poll_spread'], label='result_win', alpha=0.6)
plt.hist(result_lose['poll_spread'], label='result_lose', alpha=0.6)
plt.xlim(0, 45)
plt.legend();
# Out:
# /mnt/c/Users/Junseo/Dropbox/4thYear/1Fall/ieor135/tenguins/.env/lib/python3.6/site-packages/numpy/lib/histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /mnt/c/Users/Junseo/Dropbox/4thYear/1Fall/ieor135/tenguins/.env/lib/python3.6/site-packages/numpy/lib/histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Does this depend on party?

# %%
result_win_r = result_win[result_win['winning_party'] == 'r'] # republican led poll and won
result_win_d = result_win[result_win['winning_party'] == 'd'] # democrat led poll and won
result_win_nan = result_win[result_win['winning_party'].isnull()]

result_lose_r = result_lose[result_lose['winning_party'] == 'r'] # republican lost poll but won
result_lose_d = result_lose[result_lose['winning_party'] == 'd'] # democrat lost poll but won
result_lose_nan = result_lose[result_lose['winning_party'].isnull()]

# %%
plt.figure(figsize=(36, 24))

plt.subplot(311)
plt.hist(result_win_r['poll_spread'], label='result_win_r', alpha=0.6) # republican led poll and won
plt.hist(result_lose_r['poll_spread'], label='result_lose_r', alpha=0.6) # republican lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 75)
plt.legend()

plt.subplot(312)
plt.hist(result_win_d['poll_spread'], label='result_win_d', alpha=0.6) # democrat led poll and won
plt.hist(result_lose_d['poll_spread'], label='result_lose_d', alpha=0.6) # democrat lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 75)
plt.legend()

plt.subplot(313)
plt.hist(result_win_nan['poll_spread'], label='result_win_nan', alpha=0.6)
plt.hist(result_lose_nan['poll_spread'], label='result_lose_nan', alpha=0.6)
plt.xlim(0, 45)
plt.ylim(0, 75)
plt.legend();

# %% [markdown]
# Fascinating. When the Democrats win (second graph), they are more likely to be leading the polls in convincing fashion (blue is spread when they are leading polls, while orange is spread when they are losing the polls). On the other hand, Republicans do not necessarily win in such convincing fashion (first graph; blue is spread when they are leading polls and win, orange is when they are losing polls and spread). We do have to be careful to jump too quickly to conclusions, however, as there are many missing values.

# %% [markdown]
# # Replication on Senate, Governor

# %%
senate_polls = pd.read_pickle(DATA_DIR/'cleaned'/'SenatePollwithWinner_Final.pkl')
governor_polls = pd.read_pickle(DATA_DIR/'cleaned'/'GovernorPollwithWinner_Final.pkl')

# %%
senate_win = senate_polls[senate_polls['poll_leader'] == senate_polls['winner']]
senate_lose = senate_polls[senate_polls['poll_leader'] != senate_polls['winner']]

governor_win = governor_polls[governor_polls['poll_leader'] == governor_polls['winner']]
governor_lose = governor_polls[governor_polls['poll_leader'] != governor_polls['winner']]

# %%
senate_win_r = senate_win[senate_win['winning_party'] == 'r'] # republican led poll and won
senate_win_d = senate_win[senate_win['winning_party'] == 'd'] # democrat led poll and won
senate_win_nan = senate_win[senate_win['winning_party'].isnull()]

senate_lose_r = senate_lose[senate_lose['winning_party'] == 'r'] # republican lost poll but won
senate_lose_d = senate_lose[senate_lose['winning_party'] == 'd'] # democrat lost poll but won
senate_lose_nan = senate_lose[senate_lose['winning_party'].isnull()]

# %%
governor_win_r = governor_win[governor_win['winning_party'] == 'r'] # republican led poll and won
governor_win_d = governor_win[governor_win['winning_party'] == 'd'] # democrat led poll and won
governor_win_nan = governor_win[governor_win['winning_party'].isnull()]

governor_lose_r = governor_lose[governor_lose['winning_party'] == 'r'] # republican lost poll but won
governor_lose_d = governor_lose[governor_lose['winning_party'] == 'd'] # democrat lost poll but won
governor_lose_nan = governor_lose[governor_lose['winning_party'].isnull()]

# %%
plt.figure(figsize=(36, 24))

plt.subplot(311)
plt.hist(senate_win_r['poll_spread'], label='senate_win_r', alpha=0.6) # republican led poll and won
plt.hist(senate_lose_r['poll_spread'], label='senate_lose_r', alpha=0.6) # republican lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend()

plt.subplot(312)
plt.hist(senate_win_d['poll_spread'], label='senate_win_d', alpha=0.6) # democrat led poll and won
plt.hist(senate_lose_d['poll_spread'], label='senate_lose_d', alpha=0.6) # democrat lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend()

plt.subplot(313)
plt.hist(senate_win_nan['poll_spread'], label='senate_win_nan', alpha=0.6)
plt.hist(senate_lose_nan['poll_spread'], label='senate_lose_nan', alpha=0.6)
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend();

# %%
plt.figure(figsize=(36, 24))

plt.subplot(311)
plt.hist(governor_win_r['poll_spread'], label='governor_win_r', alpha=0.6) # republican led poll and won
plt.hist(governor_lose_r['poll_spread'], label='governor_lose_r', alpha=0.6) # republican lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend()

plt.subplot(312)
plt.hist(governor_win_d['poll_spread'], label='governor_win_d', alpha=0.6) # democrat led poll and won
plt.hist(governor_lose_d['poll_spread'], label='governor_lose_d', alpha=0.6) # democrat lost poll but won
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend()

plt.subplot(313)
plt.hist(governor_win_nan['poll_spread'], label='governor_win_nan', alpha=0.6)
plt.hist(governor_lose_nan['poll_spread'], label='governor_lose_nan', alpha=0.6)
plt.xlim(0, 45)
plt.ylim(0, 1000)
plt.legend();

# %% [markdown]
# # Load PredictIt Data

# %%
df = pd.read_csv('DailyMarketData_Fixed.csv',sep = '|')
df.head(5)
# Out:
#    MarketId                                         MarketName MarketSymbol  \
# 0      1234  Who will win the 2016 U.S. presidential election?     USPREZ16
# 1      1234  Who will win the 2016 U.S. presidential election?     USPREZ16
# 2      1234  Who will win the 2016 U.S. presidential election?     USPREZ16
# 3      1234  Who will win the 2016 U.S. presidential election?     USPREZ16
# 4      1234  Who will win the 2016 U.S. presidential election?     USPREZ16
#
#   ContractName   ContractSymbol        Date  OpenPrice  LowPrice  HighPrice  \
# 0   Ben Carson  CARSON.USPREZ16  2015-06-02       0.07      0.07       0.07
# 1   Ben Carson  CARSON.USPREZ16  2015-06-03       0.07      0.07       0.07
# 2   Ben Carson  CARSON.USPREZ16  2015-06-04       0.07      0.07       0.07
# 3   Ben Carson  CARSON.USPREZ16  2015-06-05       0.07      0.07       0.07
# 4   Ben Carson  CARSON.USPREZ16  2015-06-06       0.07      0.07       0.07
#
#    ClosePrice  Volume
# 0        0.07      25
# 1        0.07       0
# 2        0.07       0
# 3        0.07       0
# 4        0.07       0

# %% [markdown]
# # How many markets we have and how many observations we have for each market?

# %%
markets = df['MarketId'].unique()
markets
# Out:
# array([1234, 1296, 1301, 1303, 1322, 1323, 1324, 1325, 1406, 1473, 1866,
#        1920, 1998, 2015, 2029, 2052, 2099, 2100, 2101, 2102, 2103, 2112,
#        2113, 2114, 2115, 2116, 2119, 2120, 2132, 2133, 2134, 2135, 2136,
#        2138, 2139, 2173, 2174, 2196, 2201, 2202, 2219, 2220, 2230, 2233,
#        2254, 2269, 2270, 2280, 2281, 2290, 2291, 2293, 2294, 2310, 2311,
#        2336, 2339, 2340, 2341, 2342, 2355, 2356, 2357, 2370, 2373, 2374,
#        2375, 2376, 2380, 2391, 2392, 2393, 2394, 2401, 2402, 2406, 2416,
#        2417, 2418, 2419, 2431, 2432, 2436, 2437, 2438, 2439, 2605, 2631,
#        2639, 2647, 2654, 2691, 2692, 2693, 2694, 2736, 2739, 2775, 2776,
#        2777, 2778, 2779, 2792, 2793, 2794, 2795, 2896, 2924, 2926, 2932,
#        2961, 3070, 3170, 3185, 3220, 3298, 3299, 3369, 3471, 3472, 3498,
#        3499, 3582, 3583, 3584, 3766, 3783, 3827, 3868, 3873, 3874, 3899,
#        3903, 3904, 3922, 3953, 3966, 4051, 4147, 4148, 4273, 4370, 4371,
#        4372, 4373, 4473])

# %%
print('Numbers of markets in PredictIt Data:', len(markets))
# Out:
# Numbers of markets in PredictIt Data: 146

# %%
df_id = pd.DataFrame(df['MarketId'].value_counts())
df_id.columns = ['# of Observation']
df_id.index.names = ['Market ID']
print('Markets with the most observations:')
df_id.head()
# Out:
# Markets with the most observations:
#            # of Observation
# Market ID
# 1234                  21237
# 2406                   7154
# 2779                   2140
# 2777                   2068
# 1296                   2026

# %% [markdown]
# # Histogram

# %%
marketid = df['MarketId']
plt.figure(figsize=(20, 15))
pd.Series.hist(marketid, bins='auto',align='mid')
#plt.bar(rate['index'],rate['MarketId'])
plt.title("Histogram of Number of Observations per PredictIt Market", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("hist.png")
plt.show()

# %%
numofmarket = len(df_id)
observation = sum(df_id['# of Observation'])
top7percentage = sum(df_id.head(6)['# of Observation']) /  sum(df_id['# of Observation'])
print('Total numbers of markets in PredictIt Data: ', numofmarket)
print('Total numbers of observations in PredictIt Data: ', observation)
print('Percentage of the 6 markets with most numbers of observations among all observations : ', top7percentage)
# Out:
# Total numbers of markets in PredictIt Data:  146
# Total numbers of observations in PredictIt Data:  75337
# Percentage of the 6 markets with most numbers of observations among all observations :  0.48374636632730267

# %% [markdown]
# There are 146 diiferent markets in the PredictIt data with 146 and total 75337 different observations; however, almost 50% of them are in 6 markets.

# %% [markdown]
# # Load RCP Direction Data

# %%
direction = pd.read_csv('RCP_direction_final_538.csv')
direction.head()
# Out:
#    Unnamed: 0 Race/Topic (Click to Sort)                 Poll  \
# 0           0       Direction of Country  R2000/Daily Kos (D)
# 1           1       Direction of Country  R2000/Daily Kos (D)
# 2           2       Direction of Country    Rasmussen Reports
# 3           3       Direction of Country  Democracy Corps (D)
# 4           4       Direction of Country    Rasmussen Reports
#
#                               Results  Spread        Date  Year  score
# 0  Right Direction 38, Wrong Track 58     -20  2010-04-16  2010    0.0
# 1  Right Direction 39, Wrong Track 57     -18  2010-04-23  2010    0.0
# 2  Right Direction 33, Wrong Track 62     -29  2010-04-26  2010    7.0
# 3  Right Direction 34, Wrong Track 57     -23  2010-04-27  2010    8.0
# 4  Right Direction 33, Wrong Track 61     -28  2010-04-27  2010    7.0

# %% [markdown]
# # How often the poll would result in 'Right Track', 'Wrong Track', and 'Tie'?

# %%
direction = direction[['Date','Spread']]
direction = direction.groupby(['Date'])['Spread'].mean().reset_index()
direction['Date'] = pd.to_datetime(direction['Date'])
direction.set_index(['Date'],inplace=True)

# %%
right = sum(direction['Spread'] > 0)
wrong = sum(direction['Spread'] < 0)
tie = sum(direction['Spread'] == 0)
total = len(direction)
print('Total numbers of poll: ', total)
print('Percentage of Right Track: ', right/total)
print('Percentage of Wrong Track: ', wrong/ total)
print('Percentage of Tie: ', tie/total)
# Out:
# Total numbers of poll:  1010
# Percentage of Right Track:  0.0
# Percentage of Wrong Track:  0.999009900990099
# Percentage of Tie:  0.0009900990099009901

# %% [markdown]
# In the poll data we have for the country direction, we have 1010 observations. 1099 of them have a result in 'Wrong Track', 1 of them is 'Tie', and None of the observations is 'Right Track'.

# %% [markdown]
# # Plot of the Spread on the Poll of Country Direction

# %%
plt.figure(figsize=(20, 15))
direction_plot = plt.plot(direction, data=df,color = 'blue')
plt.axvline(x='2017-01-20',color='red')
direction_l = plt.legend(direction_plot,prop={'size': 20})
direction_l.get_texts()[0].set_text('Spread (+:right track; -:wrong track)')
plt.title("Direction of the Country",fontsize = 20)
#axes = plt.gca()
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# The red vertical line repesents the date when Donald Trump Inaugurate

# %% [markdown]
# # Load RCP Generic Congressional Vote Data

# %%
plt.figure(figsize=(20, 15))
generic = pd.read_csv('RCP_generic_final_538.csv')
generic.head()
# Out:
#    Unnamed: 0  Race/Topic (Click to Sort)               Poll  \
# 0           0  Generic Congressional Vote            PPP (D)
# 1           1  Generic Congressional Vote             Gallup
# 2           2  Generic Congressional Vote  Rasmussen Reports
# 3           3  Generic Congressional Vote           FOX News
# 4           4  Generic Congressional Vote  Rasmussen Reports
#
#                         Results  Spread        Date  Year  score
# 0  Republicans 47, Democrats 42      -5  2010-04-16  2010    9.0
# 1  Republicans 46, Democrats 43      -3  2010-04-19  2010    9.0
# 2  Republicans 46, Democrats 36     -10  2010-04-19  2010    7.0
# 3  Republicans 42, Democrats 38      -4  2010-04-22  2010   12.0
# 4  Republicans 44, Democrats 38      -6  2010-04-26  2010    7.0

# %% [markdown]
# # In the poll data of generic congressional vote, how often would Republicans get more votes than Democrats?

# %%
generic = generic[['Date','Spread']]
generic = generic.groupby(['Date'])['Spread'].mean().reset_index()
generic['Date'] = pd.to_datetime(generic['Date'])

# %%
dem = sum(generic['Spread'] > 0)
rep = sum(generic['Spread'] < 0)
tie = sum(generic['Spread'] == 0)
total = len(generic)
print('Total numbers of observations: ', total)
print('Percentage of Republicans Get more: ', rep/total)
print('Percentage of Democrats Get more: ', dem/ total)
print('Percentage of Tie: ', tie/total)
# Out:
# Total numbers of observations:  606
# Percentage of Republicans Get more:  0.33828382838283827
# Percentage of Democrats Get more:  0.594059405940594
# Percentage of Tie:  0.06765676567656766

# %% [markdown]
# In the poll data we have for the generic congressional vote, we have 859 observations. 541 of them have a result in Republicans get more votes, 258 of them result in Democrats get more votes, and 60 of the observations are tie.

# %% [markdown]
# # Plot of the Spread on the Poll of Generic Congressional Vote

# %%
plt.figure(figsize=(20, 15))
generic_plot = plt.plot(generic, data=df,color = 'blue')
plt.axvline(x='2017-01-20',color='red')
generic_l = plt.legend(generic_plot, prop={'size': 20})
generic_l.get_texts()[0].set_text('Spread (+:Republicans; -:Democrats)')

plt.title("Generic",fontsize = 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# The red vertical line repesents the when date Donald Trump Inaugurates

# %% [markdown]
# # Load RCP Presidential Approval Poll Data

# %%
p_approval = pd.read_csv('RCP_p_approval_final_538.csv')
p_approval.head()
# Out:
#    Unnamed: 0    Race/Topic (Click to Sort)                 Poll  \
# 0           0  President Obama Job Approval           Quinnipiac
# 1           1  President Obama Job Approval             FOX News
# 2           2  President Obama Job Approval               Gallup
# 3           3  President Obama Job Approval    Rasmussen Reports
# 4           4  President Obama Job Approval  Democracy Corps (D)
#
#                      Results  Spread        Date  Year  score
# 0  Approve 44, Disapprove 46      -2  2010-04-21  2010   11.0
# 1  Approve 46, Disapprove 46       0  2010-04-22  2010   12.0
# 2  Approve 50, Disapprove 43       7  2010-04-25  2010    9.0
# 3  Approve 45, Disapprove 54      -9  2010-04-25  2010    7.0
# 4  Approve 48, Disapprove 46       2  2010-04-27  2010    8.0

# %% [markdown]
# # In the poll data of presidential approval, how often would approval gets?

# %%
p_approval = p_approval[['Date','Spread']]
p_approval = p_approval.groupby(['Date'])['Spread'].mean().reset_index()
p_approval['Date'] = pd.to_datetime(p_approval['Date'])
p_approval.set_index(['Date'],inplace=True)
App = sum(p_approval['Spread'] > 0)
Disapp = sum(p_approval['Spread'] < 0)
tie = sum(p_approval['Spread'] == 0)
total = len(p_approval)
print('Total numbers of observations: ', total)
print('Percentage of Approval Gets more: ', App/total)
print('Percentage of Disapproval Gets more: ', Disapp/ total)
print('Percentage of Tie: ', tie/total)
# Out:
# Total numbers of observations:  1152
# Percentage of Approval Gets more:  0.24479166666666666
# Percentage of Disapproval Gets more:  0.7256944444444444
# Percentage of Tie:  0.029513888888888888

# %% [markdown]
# In the poll data we have for the presidential approval, we have 1152 observations. 282 of them have a result in approval gets more votes, 836 of them result in disapproval more votes, and 34 of the observations are tie.

# %% [markdown]
# # Plot of the Spread on the Poll of Presidential Approval

# %%
plt.figure(figsize=(20, 15))
p_approval_plot = plt.plot(p_approval, data=df,color = 'blue')
trump = plt.axvline(x='2017-01-20',color='red')
p_approval_l = plt.legend(p_approval_plot,prop={'size': 20})
p_approval_l.get_texts()[0].set_text('Spread (+:approval; -:disapproval)')
plt.title("Presidential Approval",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("p_approval.png")
#plt.savefig("p_approval.svg", format="svg")
plt.show()

# %% [markdown]
# The red vertical line repesents the when date Donald Trump Inaugurates

# %% [markdown]
# # Load RCP Congressional Job Approval Poll Data

# %%
c_approval = pd.read_csv('RCP_c_approval_final_538.csv')
c_approval.head()
# Out:
#    Unnamed: 0  Race/Topic (Click to Sort)                    Poll  \
# 0           0  Congressional Job Approval              Quinnipiac
# 1           1  Congressional Job Approval                FOX News
# 2           2  Congressional Job Approval  NBC News/Wall St. Jrnl
# 3           3  Congressional Job Approval                  Gallup
# 4           4  Congressional Job Approval    Associated Press/GfK
#
#                      Results  Spread        Date  Year  score
# 0  Approve 20, Disapprove 71     -51  2010-04-21  2010   11.0
# 1  Approve 22, Disapprove 68     -46  2010-04-22  2010   12.0
# 2  Approve 21, Disapprove 72     -51  2010-05-12  2010   11.0
# 3  Approve 21, Disapprove 75     -54  2010-05-14  2010    9.0
# 4  Approve 28, Disapprove 71     -43  2010-05-15  2010    9.0

# %% [markdown]
# # In the poll data of congressional job approval, how often would approval gets?

# %%
c_approval = pd.read_csv('RCP_c_approval_final_538.csv')
c_approval = c_approval[['Date','Spread']]
c_approval = c_approval.groupby(['Date'])['Spread'].mean().reset_index()
c_approval['Date'] = pd.to_datetime(c_approval['Date'])
c_approval.set_index(['Date'],inplace=True)
App = sum(c_approval['Spread'] > 0)
Disapp = sum(c_approval['Spread'] < 0)
tie = sum(c_approval['Spread'] == 0)
total = len(c_approval)
print('Total numbers of observations: ', total)
print('Percentage of Approval Gets more: ', App/total)
print('Percentage of Disapproval Gets more: ', Disapp/ total)
print('Percentage of Tie: ', tie/total)
# Out:
# Total numbers of observations:  573
# Percentage of Approval Gets more:  0.0
# Percentage of Disapproval Gets more:  1.0
# Percentage of Tie:  0.0

# %% [markdown]
# In the poll data we have for the presidential approval, we have 573 observations, and all of them have a result in disapproval gets more votes.

# %% [markdown]
# # Plot of the Spread on the Poll of Congressional Job Approval

# %%
plt.figure(figsize=(20, 15))
c_approval = pd.read_csv('RCP_c_approval_final_538.csv')
c_approval = c_approval[['Date','Spread']]
c_approval = c_approval.groupby(['Date'])['Spread'].mean().reset_index()
c_approval['Date'] = pd.to_datetime(c_approval['Date'])
c_approval.set_index(['Date'],inplace=True)
c_approval_plot = plt.plot(c_approval, data=df, color = 'blue', label="congress approval")
trump = plt.axvline(x='2017-01-20',color='red',label="trump")
c_approval_l = plt.legend(c_approval_plot,prop={'size': 20})
c_approval_l.get_texts()[0].set_text('Spread (+:approval; -:disapproval)')
plt.title("Congress Approval",fontsize= 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("c_approval.png")
plt.show()

# %% [markdown]
# The red vertical line repesents the when date Donald Trump Inaugurates
